# %%
import sys
import mfem.par as mfem

from mfem.common.arg_parser import ArgParser
from os.path import expanduser, join, dirname
import numpy as np
from numpy import sqrt, pi, cos, sin, hypot, arctan2
from scipy.special import erfc

from pylibROM.python_utils.StopWatch import StopWatch
from pylibROM.algo import DMD

from mfem.par import intArray, add_vector
from mpi4py import MPI
import os

# %%
num_procs = MPI.COMM_WORLD.size
myid = MPI.COMM_WORLD.rank

# %%
parser = ArgParser(description='nonlinear_elasticity')
parser.add_argument('-m', '--mesh',
                    default='beam-quad.mesh',
                    action='store', type=str,
                    help='Mesh file to use.')
parser.add_argument('-rs', '--refine-serial',
                    action='store', default=2, type=int,
                    help="Number of times to refine the mesh uniformly before parallel")
parser.add_argument('-rp', '--refine-parallel',
                    action='store', default=0, type=int,
                    help="Number of times to refine the mesh uniformly after parallel")
parser.add_argument('-o', '--order',
                    action='store', default=2, type=int,
                    help="Finite element order (polynomial degree)")
help_ode = "\n".join(["ODE solver: 1 - Backward Euler, 2 - SDIRK2, 3 - SDIRK3",
                      "\t11 - Forward Euler, 12 - RK2",
                      "\t13 - RK3 SSP, 14 - RK4."])
parser.add_argument('-s', '--ode-solver',
                    action='store', default=3, type=int,
                    help=help_ode)
parser.add_argument('-tf', '--t-final',
                    action='store', default=300.0, type=float,
                    help="Final time; start time is 0.")
parser.add_argument('-dt', '--time-step',
                    action='store', default=3.0, type=float,
                    help="Time step")
parser.add_argument("-v", "--viscosity",
                    action='store', default=1e-2, type=float,
                    help="Viscosity coefficient.")
parser.add_argument("-mu", "--shear-modulus",
                    action='store', default=0.25, type=float,
                    help="Shear modulus in the Neo-Hookean hyperelastic model.")
parser.add_argument("-K", "--bulk-modulus",
                    action='store', default=5.0, type=float,
                    help="Bulk modulus in the Neo-Hookean hyperelastic model.")
parser.add_argument('-vis', '--visualization',
                    action='store_true', default=True,
                    help='Enable GLVis visualization')
parser.add_argument('-visit', '--visit-datafiles',
                    action='store_true', default=False,
                    help="Save data files for VisIt (visit.llnl.gov) visualization.")
parser.add_argument("-vs", "--visualization-steps",
                    action='store', default=1, type=int,
                    help="Visualize every n-th timestep.")
parser.add_argument('-ef','--energy_fraction',
                    action='store', default=0.9999, type=float,
                    help='Energy fraction for DMD')
parser.add_argument('-rdim','--rdim',
                    action='store', default=-1, type=int,
                    help='Reduced dimension for DMD')
parser.add_argument('-nwinsamp','--numwindowsamples',
                    action='store', default=sys.maxsize, type=int,
                    help='Number of samples in DMD windows.');

# %%
args = parser.parse_args([])

ser_ref_levels = args.refine_serial
par_ref_levels = args.refine_parallel
order = args.order
ode_solver_type = args.ode_solver
t_final = args.t_final
dt = args.time_step
visc = args.viscosity
mu = args.shear_modulus
K = args.bulk_modulus
visualization = args.visualization
visit = args.visit_datafiles
vis_steps = args.visualization_steps
ef = args.energy_fraction
rdim = args.rdim
windowNumSamples = args.numwindowsamples

# %%
if (myid == 0):
    parser.print_options(args)

device = mfem.Device('cpu')
if myid == 0:
    device.Print()
# Out:
# Options used:
#    --mesh  beam-quad.mesh
#    --refine_serial  2
#    --refine_parallel  0
#    --order  2
#    --ode_solver  3
#    --t_final  300.0
#    --time_step  3.0
#    --viscosity  0.01
#    --shear_modulus  0.25
#    --bulk_modulus  5.0
#    --visualization  True
#    --visit_datafiles  False
#    --visualization_steps  1
#    --energy_fraction  0.9999
#    --rdim  -1
#    --numwindowsamples  9223372036854775807
# Device configuration: cpu
# Memory configuration: host-std

# %%
# 3. Read the serial mesh from the given mesh file on all processors. We can
#    handle triangular, quadrilateral, tetrahedral and hexahedral meshes
#    with the same code.
meshfile = expanduser(os.path.join('../data', args.mesh))
mesh = mfem.Mesh(meshfile, 1, 1)
dim = mesh.Dimension()

# %%
# 4. Define the ODE solver used for time integration. Several implicit
#    singly diagonal implicit Runge-Kutta (SDIRK) methods, as well as
#    explicit Runge-Kutta methods are available.
if ode_solver_type == 1:
    ode_solver = BackwardEulerSolver()
elif ode_solver_type == 2:
    ode_solver = mfem.SDIRK23Solver(2)
elif ode_solver_type == 3:
    ode_solver = mfem.SDIRK33Solver()
elif ode_solver_type == 11:
    ode_solver = ForwardEulerSolver()
elif ode_solver_type == 12:
    ode_solver = mfem.RK2Solver(0.5)
elif ode_solver_type == 13:
    ode_solver = mfem.RK3SSPSolver()
elif ode_solver_type == 14:
    ode_solver = mfem.RK4Solver()
elif ode_solver_type == 22:
    ode_solver = mfem.ImplicitMidpointSolver()
elif ode_solver_type == 23:
    ode_solver = mfem.SDIRK23Solver()
elif ode_solver_type == 24:
    ode_solver = mfem.SDIRK34Solver()
else:
    if myid == 0:
        print("Unknown ODE solver type: " + str(ode_solver_type))
    sys.exit()

# %%
# 5. Refine the mesh in serial to increase the resolution. In this example
#    we do 'ser_ref_levels' of uniform refinement, where 'ser_ref_levels' is
#    a command-line parameter.
for lev in range(ser_ref_levels):
    mesh.UniformRefinement()

# %%
# 6. Define a parallel mesh by a partitioning of the serial mesh. Refine
#    this mesh further in parallel to increase the resolution. Once the
#    parallel mesh is defined, the serial mesh can be deleted.
pmesh = mfem.ParMesh(MPI.COMM_WORLD, mesh)
del mesh
for x in range(par_ref_levels):
    pmesh.UniformRefinement()

# %%
# 7. Define the parallel vector finite element spaces representing the mesh
#    deformation x_gf, the velocity v_gf, and the initial configuration,
#    x_ref. Define also the elastic energy density, w_gf, which is in a
#    discontinuous higher-order space. Since x and v are integrated in time
#    as a system, we group them together in block vector vx, on the unique
#    parallel degrees of freedom, with offsets given by array true_offset.

fec = mfem.H1_FECollection(order, dim)
fespace = mfem.ParFiniteElementSpace(pmesh, fec, dim)
glob_size = fespace.GlobalTrueVSize()
if (myid == 0):
    print('Number of velocity/deformation unknowns: ' + str(glob_size))

true_size = fespace.TrueVSize()
true_offset = mfem.intArray(3)
true_offset[0] = 0
true_offset[1] = true_size
true_offset[2] = 2*true_size

vx = mfem.BlockVector(true_offset)

v_gf = mfem.ParGridFunction(fespace)
x_gf = mfem.ParGridFunction(fespace)

x_ref = mfem.ParGridFunction(fespace)
pmesh.GetNodes(x_ref)

w_fec = mfem.L2_FECollection(order + 1, dim)
w_fespace = mfem.ParFiniteElementSpace(pmesh, w_fec)
w_gf = mfem.ParGridFunction(w_fespace)
# Out:
# Number of velocity/deformation unknowns: 1170

# %%
# 8. Set the initial conditions for v_gf, x_gf and vx, and define the
#    boundary conditions on a beam-like mesh (see description above).


class InitialVelocity(mfem.VectorPyCoefficient):
    def EvalValue(self, x):
        dim = len(x)
        s = 0.1/64.

        v = np.zeros(len(x))
        v[-1] = s*x[0]**2*(8.0-x[0])
        v[0] = -s*x[0]**2
        return v


class InitialDeformation(mfem.VectorPyCoefficient):
    def EvalValue(self, x):
        return x.copy()


velo = InitialVelocity(dim)
v_gf.ProjectCoefficient(velo)
deform = InitialDeformation(dim)
x_gf.ProjectCoefficient(deform)

v_gf.GetTrueDofs(vx.GetBlock(0))
x_gf.GetTrueDofs(vx.GetBlock(1))

ess_bdr = mfem.intArray(fespace.GetMesh().bdr_attributes.Max())
ess_bdr.Assign(0)
ess_bdr[0] = 1

# %%
# 9. Initialize the hyperelastic operator, the GLVis visualization and print
#    the initial energies.
class ElasticEnergyCoefficient(mfem.PyCoefficient):
    def __init__(self, model, x):
        self.x = x
        self.model = model
        self.J = mfem.DenseMatrix()
        mfem.PyCoefficient.__init__(self)

    def Eval(self, T, ip):
        self.model.SetTransformation(T)
        self.x.GetVectorGradient(T, self.J)
        return self.model.EvalW(self.J)/(self.J.Det())


class ReducedSystemOperator(mfem.PyOperator):
    def __init__(self, M, S, H, ess_tdof_list):
        mfem.PyOperator.__init__(self, M.ParFESpace().TrueVSize())
        self.M = M
        self.S = S
        self.H = H
        self.Jacobian = None
        h = M.ParFESpace().TrueVSize()
        self.w = mfem.Vector(h)
        self.z = mfem.Vector(h)
        self.dt = 0.0
        self.ess_tdof_list = ess_tdof_list

    def SetParameters(self, dt, v, x):
        self.dt = dt
        self.v = v
        self.x = x

    def Mult(self, k, y):
        add_vector(self.v, self.dt, k, self.w)
        add_vector(self.x, self.dt, self.w, self.z)
        self.H.Mult(self.z, y)
        self.M.TrueAddMult(k, y)
        self.S.TrueAddMult(self.w, y)
        y.SetSubVector(self.ess_tdof_list, 0.0)

    def GetGradient(self, k):
        localJ = mfem.Add(1.0, self.M.SpMat(), self.dt, self.S.SpMat())
        add_vector(self.v, self.dt, k, self.w)
        add_vector(self.x, self.dt, self.w, self.z)
        localJ.Add(self.dt * self.dt,  self.H.GetLocalGradient(self.z))
        Jacobian = self.M.ParallelAssemble(localJ)
        Jacobian.EliminateRowsCols(self.ess_tdof_list)
        return Jacobian

# %%
class HyperelasticOperator(mfem.PyTimeDependentOperator):
    def __init__(self, fespace, ess_bdr, visc, mu, K):
        mfem.PyTimeDependentOperator.__init__(self, 2*fespace.TrueVSize(), 0.0)

        rel_tol = 1e-8
        skip_zero_entries = 0
        ref_density = 1.0

        self.ess_tdof_list = intArray()
        self.z = mfem.Vector(self.Height()//2)
        self.fespace = fespace
        self.viscosity = visc
        self.newton_solver = mfem.NewtonSolver(fespace.GetComm())

        M = mfem.ParBilinearForm(fespace)
        S = mfem.ParBilinearForm(fespace)
        H = mfem.ParNonlinearForm(fespace)
        self.M = M
        self.H = H
        self.S = S

        rho = mfem.ConstantCoefficient(ref_density)
        M.AddDomainIntegrator(mfem.VectorMassIntegrator(rho))
        M.Assemble(skip_zero_entries)
        M.Finalize(skip_zero_entries)
        self.Mmat = M.ParallelAssemble()

        fespace.GetEssentialTrueDofs(ess_bdr, self.ess_tdof_list)
        self.Mmat.EliminateRowsCols(self.ess_tdof_list)

        M_solver = mfem.CGSolver(fespace.GetComm())
        M_prec = mfem.HypreSmoother()
        M_solver.iterative_mode = False
        M_solver.SetRelTol(rel_tol)
        M_solver.SetAbsTol(0.0)
        M_solver.SetMaxIter(30)
        M_solver.SetPrintLevel(0)
        M_prec.SetType(mfem.HypreSmoother.Jacobi)
        M_solver.SetPreconditioner(M_prec)
        M_solver.SetOperator(self.Mmat)

        self.M_solver = M_solver
        self.M_prec = M_prec

        model = mfem.NeoHookeanModel(mu, K)
        H.AddDomainIntegrator(mfem.HyperelasticNLFIntegrator(model))
        H.SetEssentialTrueDofs(self.ess_tdof_list)
        self.model = model

        visc_coeff = mfem.ConstantCoefficient(visc)
        S.AddDomainIntegrator(mfem.VectorDiffusionIntegrator(visc_coeff))
        S.Assemble(skip_zero_entries)
        S.Finalize(skip_zero_entries)

        self.reduced_oper = ReducedSystemOperator(M, S, H, self.ess_tdof_list)

        J_hypreSmoother = mfem.HypreSmoother()
        J_hypreSmoother.SetType(mfem.HypreSmoother.l1Jacobi)
        J_hypreSmoother.SetPositiveDiagonal(True)
        J_prec = J_hypreSmoother

        J_minres = mfem.MINRESSolver(fespace.GetComm())
        J_minres.SetRelTol(rel_tol)
        J_minres.SetAbsTol(0.0)
        J_minres.SetMaxIter(300)
        J_minres.SetPrintLevel(-1)
        J_minres.SetPreconditioner(J_prec)

        self.J_solver = J_minres
        self.J_prec = J_prec

        newton_solver = mfem.NewtonSolver(fespace.GetComm())
        newton_solver.iterative_mode = False
        newton_solver.SetSolver(self.J_solver)
        newton_solver.SetOperator(self.reduced_oper)
        newton_solver.SetPrintLevel(1)  # print Newton iterations
        newton_solver.SetRelTol(rel_tol)
        newton_solver.SetAbsTol(0.0)
        newton_solver.SetAdaptiveLinRtol(2, 0.5, 0.9)
        newton_solver.SetMaxIter(10)
        self.newton_solver = newton_solver

    def Mult(self, vx, vx_dt):
        sc = self.Height()//2
        v = mfem.Vector(vx, 0,  sc)
        x = mfem.Vector(vx, sc,  sc)
        dv_dt = mfem.Vector(dvx_dt, 0, sc)
        dx_dt = mfem.Vector(dvx_dt, sc,  sc)

        self.H.Mult(x, z)
        if (self.viscosity != 0.0):
            S.TrueAddMult(v, z)
            z.SetSubVector(self.ess_tdof_list, 0.0)
        z.Neg()
        self.M_solver.Mult(z, dv_dt)
        dx_dt = v

    def ImplicitSolve(self, dt, vx, dvx_dt):
        sc = self.Height()//2
        v = mfem.Vector(vx, 0,  sc)
        x = mfem.Vector(vx, sc,  sc)
        dv_dt = mfem.Vector(dvx_dt, 0, sc)
        dx_dt = mfem.Vector(dvx_dt, sc,  sc)

        # By eliminating kx from the coupled system:
        # kv = -M^{-1}*[H(x + dt*kx) + S*(v + dt*kv)]
        # kx = v + dt*kv
        # we reduce it to a nonlinear equation for kv, represented by the
        # backward_euler_oper. This equation is solved with the newton_solver
        # object (using J_solver and J_prec internally).
        self.reduced_oper.SetParameters(dt, v, x)
        zero = mfem.Vector()  # empty vector is interpreted as
        # zero r.h.s. by NewtonSolver
        self.newton_solver.Mult(zero, dv_dt)
        add_vector(v, dt, dv_dt, dx_dt)

    def ElasticEnergy(self, x):
        return self.H.GetEnergy(x)

    def KineticEnergy(self, v):
        local_energy = 0.5*self.M.InnerProduct(v, v)
        energy = MPI.COMM_WORLD.allreduce(local_energy, op=MPI.SUM)
        return energy

    def GetElasticEnergyDensity(self, x, w):
        w_coeff = ElasticEnergyCoefficient(self.model, x)
        w.ProjectCoefficient(w_coeff)

# %%
def visualize(out, pmesh, deformed_nodes, field,
              field_name='', init_vis=False):
    nodes = deformed_nodes
    owns_nodes = 0

    nodes, owns_nodes = pmesh.SwapNodes(nodes, owns_nodes)

    out.send_text("parallel " + str(num_procs) + " " + str(myid))
    out.send_solution(pmesh, field)

    nodes, owns_nodes = pmesh.SwapNodes(nodes, owns_nodes)

    if (init_vis):
        out.send_text("window_size 400 400")
        out.send_text("window_title '" + field_name)
        if (pmesh.SpaceDimension() == 2):
            out.send_text("view 0 0")
            out.send_text("keys jl")
        out.send_text("keys cm")         # show colorbar and mesh
        # update value-range; keep mesh-extents fixed
        out.send_text("autoscale value")
        out.send_text("pause")
    out.flush()

# %%
oper = HyperelasticOperator(fespace, ess_bdr, visc,  mu, K)
if (visualization):
    vis_v = mfem.socketstream("localhost", 19916)
    vis_v.precision(8)
    visualize(vis_v, pmesh, x_gf, v_gf, "Velocity", True)

    MPI.COMM_WORLD.Barrier()
    vis_w = mfem.socketstream("localhost", 19916)
    oper.GetElasticEnergyDensity(x_gf, w_gf)
    vis_w.precision(8)
    visualize(vis_w, pmesh, x_gf, w_gf, "Elastic energy density", True)

ee0 = oper.ElasticEnergy(x_gf)
ke0 = oper.KineticEnergy(v_gf)

if myid == 0:
    print("initial elastic energy (EE) = " + str(ee0))
    print("initial kinetic energy (KE) = " + str(ke0))
    print("initial   total energy (TE) = " + str(ee0 + ke0))

# initialize timers
fom_timer, dmd_training_timer, dmd_prediction_timer = \
        StopWatch(), StopWatch(), StopWatch()
# Out:
# initial elastic energy (EE) = -7.936225237636615e-19
# initial kinetic energy (KE) = 0.03238095237811413
# initial   total energy (TE) = 0.03238095237811413

# %%
# 8. Perform time-integration (looping over the time iterations, ti, with a
#    time-step dt).
t = 0.
ti = 1
fom_timer.Start()
oper.SetTime(t)
ode_solver.Init(oper)
last_step = False
fom_timer.Stop()

curr_window = 0
dmd_v = []
dmd_x = []
ts = []
dmd_training_timer.Start()
dmd_v.append(DMD(vx.GetBlock(0).Size(),dt))
dmd_x.append(DMD(vx.GetBlock(1).Size(),dt))
dmd_v[curr_window].takeSample(vx.GetBlock(0).GetDataArray(), t)
dmd_x[curr_window].takeSample(vx.GetBlock(1).GetDataArray(), t)
ts.append(t)
dmd_training_timer.Stop()

while not last_step:
    fom_timer.Start()
    dt_real = min(dt, t_final - t)
    t, dt = ode_solver.Step(vx, t, dt_real)
    if (t >= t_final - 1e-8*dt):
        last_step = True
    fom_timer.Stop()

    dmd_training_timer.Start()
    dmd_v[curr_window].takeSample(vx.GetBlock(0).GetDataArray(), t)
    dmd_x[curr_window].takeSample(vx.GetBlock(1).GetDataArray(), t)
    if (last_step or (ti % windowNumSamples) == 0):
        if myid == 0 and rdim != -1 and ef != -1:
            print('Both rdim and ef are set. ef will be ignored')
        if rdim != -1:
            if myid == 0:
                print(f'Creating DMD with rdim: {rdim}')
            dmd_v[curr_window].train(rdim)
            dmd_x[curr_window].train(rdim)
        elif ef != 1:
            if myid == 0:
                print(f'Creating DMD with energy fraction: {ef}')
            dmd_v[curr_window].train(ef)
            dmd_x[curr_window].train(ef)
        if not last_step:
            curr_window += 1
            dmd_v.append(DMD(vx.GetBlock(0).Size(),dt))
            dmd_x.append(DMD(vx.GetBlock(1).Size(),dt))
            dmd_v[curr_window].takeSample(vx.GetBlock(0).GetDataArray(), t)
            dmd_x[curr_window].takeSample(vx.GetBlock(1).GetDataArray(), t)
    ts.append(t)
    dmd_training_timer.Stop()

    if (last_step or (ti % vis_steps) == 0):
        v_gf.Distribute(vx.GetBlock(0))
        x_gf.Distribute(vx.GetBlock(1))

        ee = oper.ElasticEnergy(x_gf)
        ke = oper.KineticEnergy(v_gf)

        text = ("step " + str(ti) + ", t = " + str(t) +
                ", EE = " + "{:g}".format(ee) +
                ", KE = " + "{:g}".format(ke) +
                ", dTE = " + "{:g}".format((ee+ke)-(ee0+ke0)))

        if myid == 0:
            print(text)
        if visualization:
            visualize(vis_v, pmesh, x_gf, v_gf)
            oper.GetElasticEnergyDensity(x_gf, w_gf)
            visualize(vis_w, pmesh, x_gf, w_gf)

    ti = ti + 1
# Out:
# step 1, t = 3.0, EE = 0.0031907, KE = 0.0282481, dTE = -0.000942125
# Newton iteration  0 : ||r|| = 0.148477
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.0878991, ||r||/||r_0|| = 0.592004
# Eisenstat-Walker rtol = 0.428167
# Newton iteration  2 : ||r|| = 0.0348413, ||r||/||r_0|| = 0.234658
# Eisenstat-Walker rtol = 0.253476
# Newton iteration  3 : ||r|| = 0.0110489, ||r||/||r_0|| = 0.074415
# Eisenstat-Walker rtol = 0.155943
# Newton iteration  4 : ||r|| = 0.00349608, ||r||/||r_0|| = 0.0235462
# Eisenstat-Walker rtol = 0.155383
# Newton iteration  5 : ||r|| = 0.000515975, ||r||/||r_0|| = 0.00347511
# Eisenstat-Walker rtol = 0.0452366
# Newton iteration  6 : ||r|| = 3.62715e-05, ||r||/||r_0|| = 0.00024429
# Eisenstat-Walker rtol = 0.013624
# Newton iteration  7 : ||r|| = 5.2937e-07, ||r||/||r_0|| = 3.56533e-06
# Eisenstat-Walker rtol = 0.00107054
# Newton iteration  8 : ||r|| = 5.61624e-10, ||r||/||r_0|| = 3.78256e-09
# Newton iteration  0 : ||r|| = 0.042588
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.0240164, ||r||/||r_0|| = 0.563924
# Eisenstat-Walker rtol = 0.395792
# Newton iteration  2 : ||r|| = 0.00929078, ||r||/||r_0|| = 0.218155
# Eisenstat-Walker rtol = 0.223197
# Newton iteration  3 : ||r|| = 0.00317116, ||r||/||r_0|| = 0.0744613
# Eisenstat-Walker rtol = 0.175649
# Newton iteration  4 : ||r|| = 0.000571993, ||r||/||r_0|| = 0.0134308
# Eisenstat-Walker rtol = 0.0625839
# Newton iteration  5 : ||r|| = 4.63014e-05, ||r||/||r_0|| = 0.00108719
# Eisenstat-Walker rtol = 0.0171174
# Newton iteration  6 : ||r|| = 8.23373e-07, ||r||/||r_0|| = 1.93334e-05
# Eisenstat-Walker rtol = 0.00147382
# Newton iteration  7 : ||r|| = 1.1903e-09, ||r||/||r_0|| = 2.79491e-08
# Eisenstat-Walker rtol = 2.54026e-05
# Newton iteration  8 : ||r|| = 1.49464e-13, ||r||/||r_0|| = 3.50954e-12
# Newton iteration  0 : ||r|| = 0.254094
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.140496, ||r||/||r_0|| = 0.552929
# Eisenstat-Walker rtol = 0.383381
# Newton iteration  2 : ||r|| = 0.0530047, ||r||/||r_0|| = 0.208603
# Eisenstat-Walker rtol = 0.211982
# Newton iteration  3 : ||r|| = 0.0123774, ||r||/||r_0|| = 0.0487118
# Eisenstat-Walker rtol = 0.0950411
# Newton iteration  4 : ||r|| = 0.00349966, ||r||/||r_0|| = 0.0137731
# Eisenstat-Walker rtol = 0.129522
# Newton iteration  5 : ||r|| = 0.000472433, ||r||/||r_0|| = 0.00185928
# Eisenstat-Walker rtol = 0.0391578
# Newton iteration  6 : ||r|| = 2.31382e-05, ||r||/||r_0|| = 9.10614e-05
# Eisenstat-Walker rtol = 0.00759201
# Newton iteration  7 : ||r|| = 1.84233e-07, ||r||/||r_0|| = 7.25058e-07
# Eisenstat-Walker rtol = 0.000401614
# Newton iteration  8 : ||r|| = 7.33399e-11, ||r||/||r_0|| = 2.88633e-10
# Newton iteration  0 : ||r|| = 0.0244605
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.0123751, ||r||/||r_0|| = 0.505921
# Eisenstat-Walker rtol = 0.332044
# Newton iteration  2 : ||r|| = 0.00441365, ||r||/||r_0|| = 0.18044
# Eisenstat-Walker rtol = 0.188593
# Newton iteration  3 : ||r|| = 0.00120471, ||r||/||r_0|| = 0.0492513
# Eisenstat-Walker rtol = 0.122339
# Newton iteration  4 : ||r|| = 0.000158778, ||r||/||r_0|| = 0.0064912
# Eisenstat-Walker rtol = 0.0376687
# Newton iteration  5 : ||r|| = 6.17101e-06, ||r||/||r_0|| = 0.000252285
# Eisenstat-Walker rtol = 0.00522239
# Newton iteration  6 : ||r|| = 3.22061e-08, ||r||/||r_0|| = 1.31666e-06
# Eisenstat-Walker rtol = 0.000202754
# Newton iteration  7 : ||r|| = 6.43335e-12, ||r||/||r_0|| = 2.6301e-10
# Newton iteration  0 : ||r|| = 0.0160796
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00812936, ||r||/||r_0|| = 0.505571
# Eisenstat-Walker rtol = 0.331672
# Newton iteration  2 : ||r|| = 0.00272859, ||r||/||r_0|| = 0.169693
# Eisenstat-Walker rtol = 0.170946
# Newton iteration  3 : ||r|| = 0.000642372, ||r||/||r_0|| = 0.0399495
# Eisenstat-Walker rtol = 0.0963008
# Newton iteration  4 : ||r|| = 6.70036e-05, ||r||/||r_0|| = 0.004167
# Eisenstat-Walker rtol = 0.0257985
# Newton iteration  5 : ||r|| = 1.73375e-06, ||r||/||r_0|| = 0.000107823
# Eisenstat-Walker rtol = 0.00270397
# Newton iteration  6 : ||r|| = 4.62537e-09, ||r||/||r_0|| = 2.87655e-07
# Eisenstat-Walker rtol = 6.84602e-05
# Newton iteration  7 : ||r|| = 3.35115e-13, ||r||/||r_0|| = 2.0841e-11
# Newton iteration  0 : ||r|| step 2, t = 6.0, EE = 0.0064185, KE = 0.0244818, dTE = -0.00148063
# step 3, t = 9.0, EE = 0.00810061, KE = 0.0224003, dTE = -0.00188008
# = 0.059159
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.0229089, ||r||/||r_0|| = 0.387243
# Eisenstat-Walker rtol = 0.325779
# Newton iteration  2 : ||r|| = 0.00690462, ||r||/||r_0|| = 0.116713
# Eisenstat-Walker rtol = 0.16289
# Newton iteration  3 : ||r|| = 0.00185288, ||r||/||r_0|| = 0.0313204
# Eisenstat-Walker rtol = 0.119023
# Newton iteration  4 : ||r|| = 0.000240368, ||r||/||r_0|| = 0.00406309
# Eisenstat-Walker rtol = 0.0367157
# Newton iteration  5 : ||r|| = 9.67189e-06, ||r||/||r_0|| = 0.00016349
# Eisenstat-Walker rtol = 0.00552395
# Newton iteration  6 : ||r|| = 5.30477e-08, ||r||/||r_0|| = 8.96697e-07
# Eisenstat-Walker rtol = 0.000219724
# Newton iteration  7 : ||r|| = 1.10246e-11, ||r||/||r_0|| = 1.86355e-10
# Newton iteration  0 : ||r|| = 0.0114609
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00668658, ||r||/||r_0|| = 0.583427
# Eisenstat-Walker rtol = 0.418175
# Newton iteration  2 : ||r|| = 0.00276885, ||r||/||r_0|| = 0.241591
# Eisenstat-Walker rtol = 0.243975
# Newton iteration  3 : ||r|| = 0.00068857, ||r||/||r_0|| = 0.0600801
# Eisenstat-Walker rtol = 0.10523
# Newton iteration  4 : ||r|| = 7.54095e-05, ||r||/||r_0|| = 0.00657974
# Eisenstat-Walker rtol = 0.0279154
# Newton iteration  5 : ||r|| = 2.11759e-06, ||r||/||r_0|| = 0.000184767
# Eisenstat-Walker rtol = 0.00308663
# Newton iteration  6 : ||r|| = 6.33809e-09, ||r||/||r_0|| = 5.5302e-07
# Eisenstat-Walker rtol = 8.24651e-05
# Newton iteration  7 : ||r|| = 5.432e-13, ||r||/||r_0|| = 4.73961e-11
# Newton iteration  0 : ||r|| = 0.0121721
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00680314, ||r||/||r_0|| = 0.55891
# Eisenstat-Walker rtol = 0.390113
# Newton iteration  2 : ||r|| = 0.00257983, ||r||/||r_0|| = 0.211945
# Eisenstat-Walker rtol = 0.218038
# Newton iteration  3 : ||r|| = 0.000562851, ||r||/||r_0|| = 0.0462409
# Eisenstat-Walker rtol = 0.0851451
# Newton iteration  4 : ||r|| = 5.17558e-05, ||r||/||r_0|| = 0.00425198
# Eisenstat-Walker rtol = 0.0210385
# Newton iteration  5 : ||r|| = 1.05467e-06, ||r||/||r_0|| = 8.66464e-05
# Eisenstat-Walker rtol = 0.00183722
# Newton iteration  6 : ||r|| = 1.83335e-09, ||r||/||r_0|| = 1.50618e-07
# Eisenstat-Walker rtol = 3.4232e-05
# Newton iteration  7 : ||r|| = 1.57961e-13, ||r||/||r_0|| = 1.29773e-11
# Newton iteration  0 : ||r|| = 0.0544606
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.0340762, ||r||/||r_0|| = 0.625704
# Eisenstat-Walker rtol = 0.468294
# Newton iteration  2 : ||r|| = 0.0135593, ||r||/||r_0|| = 0.248974
# Eisenstat-Walker rtol = 0.293014
# Newton iteration  3 : ||r|| = 0.00407922, ||r||/||r_0|| = 0.0749023
# Eisenstat-Walker rtol = 0.143198
# Newton iteration  4 : ||r|| = 0.000744912, ||r||/||r_0|| = 0.013678
# Eisenstat-Walker rtol = 0.063845
# Newton iteration  5 : ||r|| = 5.31205e-05, ||r||/||r_0|| = 0.000975393
# Eisenstat-Walker rtol = 0.0139434
# Newton iteration  6 : ||r|| = 7.44537e-07, ||r||/||r_0|| = 1.36711e-05
# Eisenstat-Walker rtol = 0.00100271
# Newton iteration  7 : ||r|| = 7.50448e-10, ||r||/||r_0|| = 1.37797e-08
# Eisenstat-Walker rtol = 1.41728e-05
# Newton iteration  8 : ||r|| = 1.49391e-13, ||r||/||r_0|| = 2.7431e-12
# Newton iteration  0 : ||r|| = 0.00653373
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00348548, ||r||/||r_0|| = 0.53346
# Eisenstat-Walker rtol = 0.361777
# Newton iteration  2 : ||r|| = 0.00122786, ||r||/||r_0|| = 0.187927
# Eisenstat-Walker rtol = 0.192993
# Newton iteration  3 : ||r|| = 0.000227375, ||r||/||r_0|| = 0.0348001
# Eisenstat-Walker rtol = 0.0653039
# Newton iteration  4 : ||r|| = 1.5095e-05, ||r||/||r_0|| = 0.00231032
# Eisenstat-Walker rtol = 0.0124195
# Newton iteration  5 : ||r|| = 1.84962e-07, ||r||/||r_0|| = 2.83088e-05
# Eisenstat-Walker rtol = 0.000806716
# Newton iteration  6 : ||r|| = 1.41172e-10, ||r||/||r_0|| = 2.16066e-08
# Eisenstat-Walker rtol = 9.03749e-06
# Newton iteration  7 : ||r|| = 1.32065e-13, ||r||/||r_0|| = 2.02128e-11
# Newton iteration  0 : ||r|| = 0.00883011
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00517304, ||r||/||r_0|| = 0.585841
# Eisenstat-Walker rtol = 0.420978
# Newton iteration  2 : ||r|| = 0.0020865, ||r||/||r_0|| = 0.236293
# Eisenstat-Wstep 4, t = 12.0, EE = 0.00847226, KE = 0.0217304, dTE = -0.00217828
# step 5, t = 15.0, EE = 0.0100956, KE = 0.0199024, dTE = -0.002383
# alker rtol = 0.246627
# Newton iteration  3 : ||r|| = 0.000567978, ||r||/||r_0|| = 0.0643229
# Eisenstat-Walker rtol = 0.121807
# Newton iteration  4 : ||r|| = 7.33888e-05, ||r||/||r_0|| = 0.00831121
# Eisenstat-Walker rtol = 0.0364797
# Newton iteration  5 : ||r|| = 2.51834e-06, ||r||/||r_0|| = 0.000285199
# Eisenstat-Walker rtol = 0.00426936
# Newton iteration  6 : ||r|| = 1.03457e-08, ||r||/||r_0|| = 1.17164e-06
# Eisenstat-Walker rtol = 0.000137657
# Newton iteration  7 : ||r|| = 1.39218e-12, ||r||/||r_0|| = 1.57663e-10
# Newton iteration  0 : ||r|| = 0.0417703
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.0222232, ||r||/||r_0|| = 0.532033
# Eisenstat-Walker rtol = 0.360213
# Newton iteration  2 : ||r|| = 0.00681877, ||r||/||r_0|| = 0.163245
# Eisenstat-Walker rtol = 0.191645
# Newton iteration  3 : ||r|| = 0.00148877, ||r||/||r_0|| = 0.0356418
# Eisenstat-Walker rtol = 0.0852461
# Newton iteration  4 : ||r|| = 0.000165753, ||r||/||r_0|| = 0.00396822
# Eisenstat-Walker rtol = 0.0286698
# Newton iteration  5 : ||r|| = 5.24739e-06, ||r||/||r_0|| = 0.000125625
# Eisenstat-Walker rtol = 0.00374737
# Newton iteration  6 : ||r|| = 1.96629e-08, ||r||/||r_0|| = 4.7074e-07
# Eisenstat-Walker rtol = 0.000118624
# Newton iteration  7 : ||r|| = 2.3173e-12, ||r||/||r_0|| = 5.54773e-11
# Newton iteration  0 : ||r|| = 0.00750781
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00430476, ||r||/||r_0|| = 0.573371
# Eisenstat-Walker rtol = 0.406575
# Newton iteration  2 : ||r|| = 0.00166903, ||r||/||r_0|| = 0.222306
# Eisenstat-Walker rtol = 0.233118
# Newton iteration  3 : ||r|| = 0.000376622, ||r||/||r_0|| = 0.050164
# Eisenstat-Walker rtol = 0.0899177
# Newton iteration  4 : ||r|| = 3.43611e-05, ||r||/||r_0|| = 0.00457672
# Eisenstat-Walker rtol = 0.0207733
# Newton iteration  5 : ||r|| = 7.39573e-07, ||r||/||r_0|| = 9.8507e-05
# Eisenstat-Walker rtol = 0.00200723
# Newton iteration  6 : ||r|| = 1.45125e-09, ||r||/||r_0|| = 1.93299e-07
# Eisenstat-Walker rtol = 4.16483e-05
# Newton iteration  7 : ||r|| = 1.56666e-13, ||r||/||r_0|| = 2.0867e-11
# Newton iteration  0 : ||r|| = 0.0041866
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00216749, ||r||/||r_0|| = 0.51772
# Eisenstat-Walker rtol = 0.344664
# Newton iteration  2 : ||r|| = 0.000713474, ||r||/||r_0|| = 0.170418
# Eisenstat-Walker rtol = 0.17844
# Newton iteration  3 : ||r|| = 0.000124863, ||r||/||r_0|| = 0.0298245
# Eisenstat-Walker rtol = 0.0595991
# Newton iteration  4 : ||r|| = 7.48105e-06, ||r||/||r_0|| = 0.0017869
# Eisenstat-Walker rtol = 0.0105196
# Newton iteration  5 : ||r|| = 7.73705e-08, ||r||/||r_0|| = 1.84805e-05
# Eisenstat-Walker rtol = 0.000613164
# Newton iteration  6 : ||r|| = 4.53811e-11, ||r||/||r_0|| = 1.08396e-08
# Eisenstat-Walker rtol = 5.90199e-06
# Newton iteration  7 : ||r|| = 1.50194e-13, ||r||/||r_0|| = 3.58749e-11
# Newton iteration  0 : ||r|| = 0.0211
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.0111058, ||r||/||r_0|| = 0.526343
# Eisenstat-Walker rtol = 0.354
# Newton iteration  2 : ||r|| = 0.00378136, ||r||/||r_0|| = 0.179212
# Eisenstat-Walker rtol = 0.186325
# Newton iteration  3 : ||r|| = 0.000842333, ||r||/||r_0|| = 0.0399211
# Eisenstat-Walker rtol = 0.0880594
# Newton iteration  4 : ||r|| = 7.97097e-05, ||r||/||r_0|| = 0.00377772
# Eisenstat-Walker rtol = 0.0220383
# Newton iteration  5 : ||r|| = 1.80158e-06, ||r||/||r_0|| = 8.53833e-05
# Eisenstat-Walker rtol = 0.00217244
# Newton iteration  6 : ||r|| = 3.74866e-09, ||r||/||r_0|| = 1.77662e-07
# Eisenstat-Walker rtol = 4.57922e-05
# Newton iteration  7 : ||r|| = 2.34533e-13, ||r||/||r_0|| = 1.11153e-11
# Newton iteration  0 : ||r|| = 0.0050057
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00280387, ||r||/||r_0|| = 0.560136
# Eisenstat-Walker rtol = 0.391498
# Newton iteration  2 : ||r|| = 0.0010949, ||r||/||r_0|| = 0.21873
# Eisenstat-Walker rtol = 0.219292
# Newton iteration  3 : ||r|| = 0.000234804, ||r||/||r_0|| = 0.0469074
# Eisenstat-Walker rtol = 0.0828082
# Newton iteration  4 : ||r|| = 1.88251e-05, ||r||/||r_0|| = 0.00376074
# Eisenstat-Walker rtol = 0.0168533
# Newton iteration  5 : ||r|| = 3.03684e-07, ||r||/||r_0|| = 6.06678e-05
# Eisenstat-Walker rstep 6, t = 18.0, EE = 0.0124998, KE = 0.0172631, dTE = -0.00261804
# step 7, t = 21.0, EE = 0.0139787, KE = 0.0154721, dTE = -0.00293017
# tol = 0.00125885
# Newton iteration  6 : ||r|| = 3.7663e-10, ||r||/||r_0|| = 7.52403e-08
# Eisenstat-Walker rtol = 1.98231e-05
# Newton iteration  7 : ||r|| = 1.36107e-13, ||r||/||r_0|| = 2.71904e-11
# Newton iteration  0 : ||r|| = 0.00626741
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00365697, ||r||/||r_0|| = 0.58349
# Eisenstat-Walker rtol = 0.418249
# Newton iteration  2 : ||r|| = 0.00144932, ||r||/||r_0|| = 0.231247
# Eisenstat-Walker rtol = 0.244044
# Newton iteration  3 : ||r|| = 0.00034824, ||r||/||r_0|| = 0.0555637
# Eisenstat-Walker rtol = 0.102071
# Newton iteration  4 : ||r|| = 3.60534e-05, ||r||/||r_0|| = 0.00575253
# Eisenstat-Walker rtol = 0.0254886
# Newton iteration  5 : ||r|| = 9.10971e-07, ||r||/||r_0|| = 0.000145351
# Eisenstat-Walker rtol = 0.00260186
# Newton iteration  6 : ||r|| = 2.31346e-09, ||r||/||r_0|| = 3.69126e-07
# Eisenstat-Walker rtol = 6.32135e-05
# Newton iteration  7 : ||r|| = 2.08164e-13, ||r||/||r_0|| = 3.32137e-11
# Newton iteration  0 : ||r|| = 0.025246
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.0129641, ||r||/||r_0|| = 0.513513
# Eisenstat-Walker rtol = 0.340144
# Newton iteration  2 : ||r|| = 0.0041497, ||r||/||r_0|| = 0.164371
# Eisenstat-Walker rtol = 0.174668
# Newton iteration  3 : ||r|| = 0.000920036, ||r||/||r_0|| = 0.0364429
# Eisenstat-Walker rtol = 0.0873904
# Newton iteration  4 : ||r|| = 9.27611e-05, ||r||/||r_0|| = 0.00367429
# Eisenstat-Walker rtol = 0.024419
# Newton iteration  5 : ||r|| = 2.23519e-06, ||r||/||r_0|| = 8.85364e-05
# Eisenstat-Walker rtol = 0.00240956
# Newton iteration  6 : ||r|| = 5.21979e-09, ||r||/||r_0|| = 2.06757e-07
# Eisenstat-Walker rtol = 5.51928e-05
# Newton iteration  7 : ||r|| = 3.1144e-13, ||r||/||r_0|| = 1.23362e-11
# Newton iteration  0 : ||r|| = 0.00680188
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00335885, ||r||/||r_0|| = 0.493812
# Eisenstat-Walker rtol = 0.325779
# Newton iteration  2 : ||r|| = 0.00115385, ||r||/||r_0|| = 0.169637
# Eisenstat-Walker rtol = 0.177487
# Newton iteration  3 : ||r|| = 0.000218326, ||r||/||r_0|| = 0.0320979
# Eisenstat-Walker rtol = 0.0676221
# Newton iteration  4 : ||r|| = 1.47158e-05, ||r||/||r_0|| = 0.0021635
# Eisenstat-Walker rtol = 0.0127281
# Newton iteration  5 : ||r|| = 1.91346e-07, ||r||/||r_0|| = 2.81313e-05
# Eisenstat-Walker rtol = 0.00088806
# Newton iteration  6 : ||r|| = 1.62297e-10, ||r||/||r_0|| = 2.38607e-08
# Eisenstat-Walker rtol = 1.07201e-05
# Newton iteration  7 : ||r|| = 1.44859e-13, ||r||/||r_0|| = 2.12969e-11
# Newton iteration  0 : ||r|| = 0.0103202
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.0058545, ||r||/||r_0|| = 0.567283
# Eisenstat-Walker rtol = 0.399614
# Newton iteration  2 : ||r|| = 0.00226796, ||r||/||r_0|| = 0.219759
# Eisenstat-Walker rtol = 0.226694
# Newton iteration  3 : ||r|| = 0.000577098, ||r||/||r_0|| = 0.0559191
# Eisenstat-Walker rtol = 0.10921
# Newton iteration  4 : ||r|| = 6.49229e-05, ||r||/||r_0|| = 0.00629084
# Eisenstat-Walker rtol = 0.0291558
# Newton iteration  5 : ||r|| = 1.88517e-06, ||r||/||r_0|| = 0.000182667
# Eisenstat-Walker rtol = 0.00325841
# Newton iteration  6 : ||r|| = 6.05542e-09, ||r||/||r_0|| = 5.86753e-07
# Eisenstat-Walker rtol = 9.24502e-05
# Newton iteration  7 : ||r|| = 5.78133e-13, ||r||/||r_0|| = 5.60194e-11
# Newton iteration  0 : ||r|| = 0.0479546
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.0278446, ||r||/||r_0|| = 0.580645
# Eisenstat-Walker rtol = 0.414954
# Newton iteration  2 : ||r|| = 0.0098608, ||r||/||r_0|| = 0.205628
# Eisenstat-Walker rtol = 0.240941
# Newton iteration  3 : ||r|| = 0.00237964, ||r||/||r_0|| = 0.0496228
# Eisenstat-Walker rtol = 0.100236
# Newton iteration  4 : ||r|| = 0.000554919, ||r||/||r_0|| = 0.0115717
# Eisenstat-Walker rtol = 0.09483
# Newton iteration  5 : ||r|| = 6.09186e-05, ||r||/||r_0|| = 0.00127034
# Eisenstat-Walker rtol = 0.0280239
# Newton iteration  6 : ||r|| = 1.59437e-06, ||r||/||r_0|| = 3.32475e-05
# Eisenstat-Walker rtol = 0.00275429
# Newton iteration  7 : ||r|| = 4.48719e-09, ||r||/||r_0|| = 9.35715e-08
# Eisenstat-Walker rtol = 7.46481e-05
# Newton iteration  8 : ||r|| = 3.59015e-13, ||r||/||r_0|| = 7.48656e-12
# Newton iteration  0 step 8, t = 24.0, EE = 0.0122796, KE = 0.0166447, dTE = -0.00345674
# : ||r|| = 0.0123209
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00679114, ||r||/||r_0|| = 0.55119
# Eisenstat-Walker rtol = 0.381432
# Newton iteration  2 : ||r|| = 0.0025988, ||r||/||r_0|| = 0.210927
# Eisenstat-Walker rtol = 0.211351
# Newton iteration  3 : ||r|| = 0.00103365, ||r||/||r_0|| = 0.0838944
# Eisenstat-Walker rtol = 0.224979
# Newton iteration  4 : ||r|| = 0.00027903, ||r||/||r_0|| = 0.0226469
# Eisenstat-Walker rtol = 0.120167
# Newton iteration  5 : ||r|| = 3.30223e-05, ||r||/||r_0|| = 0.00268019
# Eisenstat-Walker rtol = 0.0316472
# Newton iteration  6 : ||r|| = 1.03141e-06, ||r||/||r_0|| = 8.37128e-05
# Eisenstat-Walker rtol = 0.00366652
# Newton iteration  7 : ||r|| = 3.75548e-09, ||r||/||r_0|| = 3.04807e-07
# Eisenstat-Walker rtol = 0.000113238
# Newton iteration  8 : ||r|| = 4.40406e-13, ||r||/||r_0|| = 3.57448e-11
# Newton iteration  0 : ||r|| = 0.0231952
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.0138225, ||r||/||r_0|| = 0.595923
# Eisenstat-Walker rtol = 0.432762
# Newton iteration  2 : ||r|| = 0.00537733, ||r||/||r_0|| = 0.231829
# Eisenstat-Walker rtol = 0.257893
# Newton iteration  3 : ||r|| = 0.00150599, ||r||/||r_0|| = 0.0649268
# Eisenstat-Walker rtol = 0.127538
# Newton iteration  4 : ||r|| = 0.000203992, ||r||/||r_0|| = 0.00879458
# Eisenstat-Walker rtol = 0.0393739
# Newton iteration  5 : ||r|| = 8.20869e-06, ||r||/||r_0|| = 0.000353896
# Eisenstat-Walker rtol = 0.00552452
# Newton iteration  6 : ||r|| = 4.41099e-08, ||r||/||r_0|| = 1.90168e-06
# Eisenstat-Walker rtol = 0.000212563
# Newton iteration  7 : ||r|| = 9.32063e-12, ||r||/||r_0|| = 4.01835e-10
# Newton iteration  0 : ||r|| = 0.113384
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.0653516, ||r||/||r_0|| = 0.576373
# Eisenstat-Walker rtol = 0.410025
# Newton iteration  2 : ||r|| = 0.0233127, ||r||/||r_0|| = 0.205607
# Eisenstat-Walker rtol = 0.236327
# Newton iteration  3 : ||r|| = 0.00524555, ||r||/||r_0|| = 0.0462635
# Eisenstat-Walker rtol = 0.0895027
# Newton iteration  4 : ||r|| = 0.00102524, ||r||/||r_0|| = 0.00904216
# Eisenstat-Walker rtol = 0.0712638
# Newton iteration  5 : ||r|| = 8.45217e-05, ||r||/||r_0|| = 0.000745445
# Eisenstat-Walker rtol = 0.0176312
# Newton iteration  6 : ||r|| = 1.50061e-06, ||r||/||r_0|| = 1.32347e-05
# Eisenstat-Walker rtol = 0.00146996
# Newton iteration  7 : ||r|| = 2.18043e-09, ||r||/||r_0|| = 1.92304e-08
# Eisenstat-Walker rtol = 2.56132e-05
# Newton iteration  8 : ||r|| = 1.53885e-13, ||r||/||r_0|| = 1.35719e-12
# Newton iteration  0 : ||r|| = 0.0233799
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.0140333, ||r||/||r_0|| = 0.600229
# Eisenstat-Walker rtol = 0.437833
# Newton iteration  2 : ||r|| = 0.00508512, ||r||/||r_0|| = 0.2175
# Eisenstat-Walker rtol = 0.2628
# Newton iteration  3 : ||r|| = 0.00139069, ||r||/||r_0|| = 0.0594824
# Eisenstat-Walker rtol = 0.122725
# Newton iteration  4 : ||r|| = 0.000162592, ||r||/||r_0|| = 0.00695433
# Eisenstat-Walker rtol = 0.0310297
# Newton iteration  5 : ||r|| = 5.38194e-06, ||r||/||r_0|| = 0.000230195
# Eisenstat-Walker rtol = 0.00402765
# Newton iteration  6 : ||r|| = 2.11676e-08, ||r||/||r_0|| = 9.05374e-07
# Eisenstat-Walker rtol = 0.000128291
# Newton iteration  7 : ||r|| = 2.53268e-12, ||r||/||r_0|| = 1.08327e-10
# Newton iteration  0 : ||r|| = 0.0425624
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.0246867, ||r||/||r_0|| = 0.580012
# Eisenstat-Walker rtol = 0.414222
# Newton iteration  2 : ||r|| = 0.00866375, ||r||/||r_0|| = 0.203554
# Eisenstat-Walker rtol = 0.240254
# Newton iteration  3 : ||r|| = 0.00211438, ||r||/||r_0|| = 0.0496773
# Eisenstat-Walker rtol = 0.102075
# Newton iteration  4 : ||r|| = 0.00026463, ||r||/||r_0|| = 0.00621747
# Eisenstat-Walker rtol = 0.0346459
# Newton iteration  5 : ||r|| = 9.78353e-06, ||r||/||r_0|| = 0.000229863
# Eisenstat-Walker rtol = 0.00481662
# Newton iteration  6 : ||r|| = 4.67544e-08, ||r||/||r_0|| = 1.09849e-06
# Eisenstat-Walker rtol = 0.000175821
# Newton iteration  7 : ||r|| = 7.96862e-12, ||r||/||r_0|| = 1.87222e-10
# Newton iteration  0 : ||r|| = 0.184082
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.104258, ||r||/||r_0|| = 0.566367
# Eisensstep 9, t = 27.0, EE = 0.00896612, KE = 0.0191881, dTE = -0.00422668
# step 10, t = 30.0, EE = 0.00619438, KE = 0.0211999, dTE = -0.00498665
# tat-Walker rtol = 0.398569
# Newton iteration  2 : ||r|| = 0.0359509, ||r||/||r_0|| = 0.195298
# Eisenstat-Walker rtol = 0.225736
# Newton iteration  3 : ||r|| = 0.00792663, ||r||/||r_0|| = 0.0430604
# Eisenstat-Walker rtol = 0.0866095
# Newton iteration  4 : ||r|| = 0.00100984, ||r||/||r_0|| = 0.00548582
# Eisenstat-Walker rtol = 0.0356553
# Newton iteration  5 : ||r|| = 4.36704e-05, ||r||/||r_0|| = 0.000237233
# Eisenstat-Walker rtol = 0.0062072
# Newton iteration  6 : ||r|| = 2.89642e-07, ||r||/||r_0|| = 1.57344e-06
# Eisenstat-Walker rtol = 0.000298811
# Newton iteration  7 : ||r|| = 8.53748e-11, ||r||/||r_0|| = 4.63787e-10
# Newton iteration  0 : ||r|| = 0.00693359
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00369669, ||r||/||r_0|| = 0.533157
# Eisenstat-Walker rtol = 0.361445
# Newton iteration  2 : ||r|| = 0.00130443, ||r||/||r_0|| = 0.188133
# Eisenstat-Walker rtol = 0.192707
# Newton iteration  3 : ||r|| = 0.000273645, ||r||/||r_0|| = 0.0394666
# Eisenstat-Walker rtol = 0.0799088
# Newton iteration  4 : ||r|| = 2.30779e-05, ||r||/||r_0|| = 0.00332843
# Eisenstat-Walker rtol = 0.0182913
# Newton iteration  5 : ||r|| = 4.20138e-07, ||r||/||r_0|| = 6.05946e-05
# Eisenstat-Walker rtol = 0.00153087
# Newton iteration  6 : ||r|| = 6.20883e-10, ||r||/||r_0|| = 8.95471e-08
# Eisenstat-Walker rtol = 2.63236e-05
# Newton iteration  7 : ||r|| = 1.46671e-13, ||r||/||r_0|| = 2.11538e-11
# Newton iteration  0 : ||r|| = 0.0315581
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.0186918, ||r||/||r_0|| = 0.592299
# Eisenstat-Walker rtol = 0.428513
# Newton iteration  2 : ||r|| = 0.00717791, ||r||/||r_0|| = 0.227451
# Eisenstat-Walker rtol = 0.253807
# Newton iteration  3 : ||r|| = 0.00181783, ||r||/||r_0|| = 0.0576025
# Eisenstat-Walker rtol = 0.10876
# Newton iteration  4 : ||r|| = 0.000468032, ||r||/||r_0|| = 0.0148308
# Eisenstat-Walker rtol = 0.111309
# Newton iteration  5 : ||r|| = 6.19408e-05, ||r||/||r_0|| = 0.00196275
# Eisenstat-Walker rtol = 0.0379212
# Newton iteration  6 : ||r|| = 2.33088e-06, ||r||/||r_0|| = 7.38601e-05
# Eisenstat-Walker rtol = 0.00495657
# Newton iteration  7 : ||r|| = 1.09177e-08, ||r||/||r_0|| = 3.45955e-07
# Eisenstat-Walker rtol = 0.000170204
# Newton iteration  8 : ||r|| = 1.8441e-12, ||r||/||r_0|| = 5.84351e-11
# Newton iteration  0 : ||r|| = 0.16483
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.0930909, ||r||/||r_0|| = 0.564769
# Eisenstat-Walker rtol = 0.396752
# Newton iteration  2 : ||r|| = 0.0347497, ||r||/||r_0|| = 0.210821
# Eisenstat-Walker rtol = 0.224073
# Newton iteration  3 : ||r|| = 0.00790379, ||r||/||r_0|| = 0.0479511
# Eisenstat-Walker rtol = 0.0910788
# Newton iteration  4 : ||r|| = 0.00112614, ||r||/||r_0|| = 0.00683214
# Eisenstat-Walker rtol = 0.0427318
# Newton iteration  5 : ||r|| = 5.64997e-05, ||r||/||r_0|| = 0.000342776
# Eisenstat-Walker rtol = 0.00789386
# Newton iteration  6 : ||r|| = 4.70095e-07, ||r||/||r_0|| = 2.852e-06
# Eisenstat-Walker rtol = 0.000431236
# Newton iteration  7 : ||r|| = 1.92799e-10, ||r||/||r_0|| = 1.16968e-09
# Newton iteration  0 : ||r|| = 0.0183738
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00995495, ||r||/||r_0|| = 0.541801
# Eisenstat-Walker rtol = 0.370974
# Newton iteration  2 : ||r|| = 0.00310168, ||r||/||r_0|| = 0.16881
# Eisenstat-Walker rtol = 0.200994
# Newton iteration  3 : ||r|| = 0.000656281, ||r||/||r_0|| = 0.0357183
# Eisenstat-Walker rtol = 0.081026
# Newton iteration  4 : ||r|| = 5.57655e-05, ||r||/||r_0|| = 0.00303505
# Eisenstat-Walker rtol = 0.0185153
# Newton iteration  5 : ||r|| = 1.01462e-06, ||r||/||r_0|| = 5.52212e-05
# Eisenstat-Walker rtol = 0.00152941
# Newton iteration  6 : ||r|| = 1.54208e-09, ||r||/||r_0|| = 8.39284e-08
# Eisenstat-Walker rtol = 2.75462e-05
# Newton iteration  7 : ||r|| = 1.62846e-13, ||r||/||r_0|| = 8.86293e-12
# Newton iteration  0 : ||r|| = 0.0256033
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.0157763, ||r||/||r_0|| = 0.616183
# Eisenstat-Walker rtol = 0.456818
# Newton iteration  2 : ||r|| = 0.00572868, ||r||/||r_0|| = 0.223747
# Eisenstat-Walker rtol = 0.281483
# Newton iteration  3 : ||r|| = 0.00163575, ||r||/||r_0|| = 0.0638883
# Eisenstat-Walker rtol =step 11, t = 33.0, EE = 0.0046402, KE = 0.0220363, dTE = -0.00570448
# step 12, t = 36.0, EE = 0.00489376, KE = 0.0210615, dTE = -0.00642574
#  0.131597
# Newton iteration  4 : ||r|| = 0.000233329, ||r||/||r_0|| = 0.00911321
# Eisenstat-Walker rtol = 0.0428103
# Newton iteration  5 : ||r|| = 1.01425e-05, ||r||/||r_0|| = 0.000396141
# Eisenstat-Walker rtol = 0.0062593
# Newton iteration  6 : ||r|| = 6.32498e-08, ||r||/||r_0|| = 2.47037e-06
# Eisenstat-Walker rtol = 0.000270455
# Newton iteration  7 : ||r|| = 1.6999e-11, ||r||/||r_0|| = 6.63937e-10
# Newton iteration  0 : ||r|| = 0.141344
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.0817205, ||r||/||r_0|| = 0.578167
# Eisenstat-Walker rtol = 0.412092
# Newton iteration  2 : ||r|| = 0.0313876, ||r||/||r_0|| = 0.222065
# Eisenstat-Walker rtol = 0.238258
# Newton iteration  3 : ||r|| = 0.00667484, ||r||/||r_0|| = 0.047224
# Eisenstat-Walker rtol = 0.0816897
# Newton iteration  4 : ||r|| = 0.000584412, ||r||/||r_0|| = 0.00413467
# Eisenstat-Walker rtol = 0.0194343
# Newton iteration  5 : ||r|| = 1.3469e-05, ||r||/||r_0|| = 9.52919e-05
# Eisenstat-Walker rtol = 0.00224211
# Newton iteration  6 : ||r|| = 3.09016e-08, ||r||/||r_0|| = 2.18626e-07
# Eisenstat-Walker rtol = 5.36335e-05
# Newton iteration  7 : ||r|| = 1.61628e-12, ||r||/||r_0|| = 1.1435e-11
# Newton iteration  0 : ||r|| = 0.0075972
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00433067, ||r||/||r_0|| = 0.570036
# Eisenstat-Walker rtol = 0.402756
# Newton iteration  2 : ||r|| = 0.00166831, ||r||/||r_0|| = 0.219595
# Eisenstat-Walker rtol = 0.229585
# Newton iteration  3 : ||r|| = 0.000420223, ||r||/||r_0|| = 0.0553129
# Eisenstat-Walker rtol = 0.107431
# Newton iteration  4 : ||r|| = 4.63447e-05, ||r||/||r_0|| = 0.00610023
# Eisenstat-Walker rtol = 0.0282335
# Newton iteration  5 : ||r|| = 1.30958e-06, ||r||/||r_0|| = 0.000172377
# Eisenstat-Walker rtol = 0.00311802
# Newton iteration  6 : ||r|| = 4.01625e-09, ||r||/||r_0|| = 5.28649e-07
# Eisenstat-Walker rtol = 8.57785e-05
# Newton iteration  7 : ||r|| = 3.54829e-13, ||r||/||r_0|| = 4.67052e-11
# Newton iteration  0 : ||r|| = 0.0259974
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.0161522, ||r||/||r_0|| = 0.621301
# Eisenstat-Walker rtol = 0.462973
# Newton iteration  2 : ||r|| = 0.00578671, ||r||/||r_0|| = 0.222588
# Eisenstat-Walker rtol = 0.287646
# Newton iteration  3 : ||r|| = 0.00143009, ||r||/||r_0|| = 0.0550092
# Eisenstat-Walker rtol = 0.133172
# Newton iteration  4 : ||r|| = 0.000260029, ||r||/||r_0|| = 0.0100021
# Eisenstat-Walker rtol = 0.0634017
# Newton iteration  5 : ||r|| = 1.85659e-05, ||r||/||r_0|| = 0.000714144
# Eisenstat-Walker rtol = 0.0139713
# Newton iteration  6 : ||r|| = 2.5589e-07, ||r||/||r_0|| = 9.84292e-06
# Eisenstat-Walker rtol = 0.000975857
# Newton iteration  7 : ||r|| = 2.46772e-10, ||r||/||r_0|| = 9.4922e-09
# Newton iteration  0 : ||r|| = 0.137758
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.0808363, ||r||/||r_0|| = 0.586798
# Eisenstat-Walker rtol = 0.422092
# Newton iteration  2 : ||r|| = 0.0283841, ||r||/||r_0|| = 0.206043
# Eisenstat-Walker rtol = 0.247683
# Newton iteration  3 : ||r|| = 0.00608742, ||r||/||r_0|| = 0.0441891
# Eisenstat-Walker rtol = 0.104545
# Newton iteration  4 : ||r|| = 0.000672029, ||r||/||r_0|| = 0.00487831
# Eisenstat-Walker rtol = 0.0282792
# Newton iteration  5 : ||r|| = 3.80896e-05, ||r||/||r_0|| = 0.000276496
# Eisenstat-Walker rtol = 0.00961588
# Newton iteration  6 : ||r|| = 4.44072e-07, ||r||/||r_0|| = 3.22355e-06
# Eisenstat-Walker rtol = 0.000744335
# Newton iteration  7 : ||r|| = 3.1737e-10, ||r||/||r_0|| = 2.30381e-09
# Newton iteration  0 : ||r|| = 0.00983189
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.0063935, ||r||/||r_0|| = 0.650282
# Eisenstat-Walker rtol = 0.498417
# Newton iteration  2 : ||r|| = 0.00299613, ||r||/||r_0|| = 0.304736
# Eisenstat-Walker rtol = 0.324111
# Newton iteration  3 : ||r|| = 0.000957171, ||r||/||r_0|| = 0.0973537
# Eisenstat-Walker rtol = 0.161542
# Newton iteration  4 : ||r|| = 0.000175613, ||r||/||r_0|| = 0.0178615
# Eisenstat-Walker rtol = 0.0643317
# Newton iteration  5 : ||r|| = 1.16905e-05, ||r||/||r_0|| = 0.00118904
# Eisenstat-Walker rtol = 0.0124744
# Newton iteration  6 : ||r|| = 1.42764e-07, ||r||/||r_0|| = 1.45205e-05
# Eisenstat-Walker rtol = 0.000802337
# Nstep 13, t = 39.0, EE = 0.0064974, KE = 0.0187461, dTE = -0.00713748
# step 14, t = 42.0, EE = 0.00835926, KE = 0.0162476, dTE = -0.00777409
# ewton iteration  7 : ||r|| = 1.13924e-10, ||r||/||r_0|| = 1.15872e-08
# Eisenstat-Walker rtol = 9.71235e-06
# Newton iteration  8 : ||r|| = 1.57949e-13, ||r||/||r_0|| = 1.60649e-11
# Newton iteration  0 : ||r|| = 0.0285
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.0174676, ||r||/||r_0|| = 0.612898
# Eisenstat-Walker rtol = 0.452884
# Newton iteration  2 : ||r|| = 0.00639237, ||r||/||r_0|| = 0.224294
# Eisenstat-Walker rtol = 0.277571
# Newton iteration  3 : ||r|| = 0.00169457, ||r||/||r_0|| = 0.0594586
# Eisenstat-Walker rtol = 0.125708
# Newton iteration  4 : ||r|| = 0.000281867, ||r||/||r_0|| = 0.00989004
# Eisenstat-Walker rtol = 0.054894
# Newton iteration  5 : ||r|| = 1.6583e-05, ||r||/||r_0|| = 0.000581859
# Eisenstat-Walker rtol = 0.0102142
# Newton iteration  6 : ||r|| = 1.6516e-07, ||r||/||r_0|| = 5.79506e-06
# Eisenstat-Walker rtol = 0.00057688
# Newton iteration  7 : ||r|| = 9.32078e-11, ||r||/||r_0|| = 3.27045e-09
# Newton iteration  0 : ||r|| = 0.148205
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.0864821, ||r||/||r_0|| = 0.583528
# Eisenstat-Walker rtol = 0.418293
# Newton iteration  2 : ||r|| = 0.0312974, ||r||/||r_0|| = 0.211176
# Eisenstat-Walker rtol = 0.244086
# Newton iteration  3 : ||r|| = 0.00669901, ||r||/||r_0|| = 0.0452009
# Eisenstat-Walker rtol = 0.102099
# Newton iteration  4 : ||r|| = 0.000744697, ||r||/||r_0|| = 0.00502476
# Eisenstat-Walker rtol = 0.0285986
# Newton iteration  5 : ||r|| = 3.32004e-05, ||r||/||r_0|| = 0.000224016
# Eisenstat-Walker rtol = 0.00652081
# Newton iteration  6 : ||r|| = 2.49851e-07, ||r||/||r_0|| = 1.68584e-06
# Eisenstat-Walker rtol = 0.000366577
# Newton iteration  7 : ||r|| = 8.72413e-11, ||r||/||r_0|| = 5.88651e-10
# Newton iteration  0 : ||r|| = 0.0104226
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00668457, ||r||/||r_0|| = 0.641352
# Eisenstat-Walker rtol = 0.487389
# Newton iteration  2 : ||r|| = 0.00294365, ||r||/||r_0|| = 0.282429
# Eisenstat-Walker rtol = 0.312588
# Newton iteration  3 : ||r|| = 0.000940118, ||r||/||r_0|| = 0.0901998
# Eisenstat-Walker rtol = 0.157737
# Newton iteration  4 : ||r|| = 0.000144466, ||r||/||r_0|| = 0.0138608
# Eisenstat-Walker rtol = 0.0482906
# Newton iteration  5 : ||r|| = 6.88348e-06, ||r||/||r_0|| = 0.000660437
# Eisenstat-Walker rtol = 0.00726154
# Newton iteration  6 : ||r|| = 4.72035e-08, ||r||/||r_0|| = 4.52894e-06
# Eisenstat-Walker rtol = 0.000315386
# Newton iteration  7 : ||r|| = 1.50973e-11, ||r||/||r_0|| = 1.44851e-09
# Newton iteration  0 : ||r|| = 0.030625
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.0184014, ||r||/||r_0|| = 0.600864
# Eisenstat-Walker rtol = 0.438583
# Newton iteration  2 : ||r|| = 0.00676207, ||r||/||r_0|| = 0.220802
# Eisenstat-Walker rtol = 0.263529
# Newton iteration  3 : ||r|| = 0.00176148, ||r||/||r_0|| = 0.0575179
# Eisenstat-Walker rtol = 0.115579
# Newton iteration  4 : ||r|| = 0.000275122, ||r||/||r_0|| = 0.00898358
# Eisenstat-Walker rtol = 0.0495785
# Newton iteration  5 : ||r|| = 1.43526e-05, ||r||/||r_0|| = 0.000468656
# Eisenstat-Walker rtol = 0.00840847
# Newton iteration  6 : ||r|| = 1.1624e-07, ||r||/||r_0|| = 3.79559e-06
# Eisenstat-Walker rtol = 0.00041282
# Newton iteration  7 : ||r|| = 4.72908e-11, ||r||/||r_0|| = 1.54419e-09
# Newton iteration  0 : ||r|| = 0.155647
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.0890915, ||r||/||r_0|| = 0.572396
# Eisenstat-Walker rtol = 0.405457
# Newton iteration  2 : ||r|| = 0.0322568, ||r||/||r_0|| = 0.207244
# Eisenstat-Walker rtol = 0.232082
# Newton iteration  3 : ||r|| = 0.00710174, ||r||/||r_0|| = 0.0456273
# Eisenstat-Walker rtol = 0.0864046
# Newton iteration  4 : ||r|| = 0.000724513, ||r||/||r_0|| = 0.00465486
# Eisenstat-Walker rtol = 0.0248893
# Newton iteration  5 : ||r|| = 2.33829e-05, ||r||/||r_0|| = 0.00015023
# Eisenstat-Walker rtol = 0.00386608
# Newton iteration  6 : ||r|| = 9.52372e-08, ||r||/||r_0|| = 6.11881e-07
# Eisenstat-Walker rtol = 0.000135754
# Newton iteration  7 : ||r|| = 1.26658e-11, ||r||/||r_0|| = 8.13756e-11
# Newton iteration  0 : ||r|| = 0.00533663
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00288296, ||r||/||r_0|| = 0.540221
# Eisenstat-Walker step 15, t = 45.0, EE = 0.0101246, KE = 0.0139725, dTE = -0.00828391
# rtol = 0.369225
# Newton iteration  2 : ||r|| = 0.00103581, ||r||/||r_0|| = 0.194094
# Eisenstat-Walker rtol = 0.199463
# Newton iteration  3 : ||r|| = 0.000203642, ||r||/||r_0|| = 0.0381592
# Eisenstat-Walker rtol = 0.0719452
# Newton iteration  4 : ||r|| = 1.42467e-05, ||r||/||r_0|| = 0.0026696
# Eisenstat-Walker rtol = 0.0135183
# Newton iteration  5 : ||r|| = 1.91402e-07, ||r||/||r_0|| = 3.58657e-05
# Eisenstat-Walker rtol = 0.000936306
# Newton iteration  6 : ||r|| = 1.80028e-10, ||r||/||r_0|| = 3.37344e-08
# Eisenstat-Walker rtol = 1.26721e-05
# Newton iteration  7 : ||r|| = 1.58265e-13, ||r||/||r_0|| = 2.96564e-11
# Newton iteration  0 : ||r|| = 0.0252182
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.0150401, ||r||/||r_0|| = 0.596398
# Eisenstat-Walker rtol = 0.433321
# Newton iteration  2 : ||r|| = 0.00559284, ||r||/||r_0|| = 0.221778
# Eisenstat-Walker rtol = 0.258432
# Newton iteration  3 : ||r|| = 0.00143954, ||r||/||r_0|| = 0.0570833
# Eisenstat-Walker rtol = 0.111984
# Newton iteration  4 : ||r|| = 0.000175556, ||r||/||r_0|| = 0.00696148
# Eisenstat-Walker rtol = 0.0332222
# Newton iteration  5 : ||r|| = 6.20561e-06, ||r||/||r_0|| = 0.000246077
# Eisenstat-Walker rtol = 0.00447932
# Newton iteration  6 : ||r|| = 2.67063e-08, ||r||/||r_0|| = 1.05901e-06
# Eisenstat-Walker rtol = 0.000148407
# Newton iteration  7 : ||r|| = 3.90221e-12, ||r||/||r_0|| = 1.54738e-10
# Newton iteration  0 : ||r|| = 0.13992
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.0782193, ||r||/||r_0|| = 0.559027
# Eisenstat-Walker rtol = 0.390245
# Newton iteration  2 : ||r|| = 0.0281348, ||r||/||r_0|| = 0.201077
# Eisenstat-Walker rtol = 0.218158
# Newton iteration  3 : ||r|| = 0.00608542, ||r||/||r_0|| = 0.043492
# Eisenstat-Walker rtol = 0.0839623
# Newton iteration  4 : ||r|| = 0.000565934, ||r||/||r_0|| = 0.00404468
# Eisenstat-Walker rtol = 0.0214268
# Newton iteration  5 : ||r|| = 2.85553e-05, ||r||/||r_0|| = 0.000204082
# Eisenstat-Walker rtol = 0.00796675
# Newton iteration  6 : ||r|| = 2.61514e-07, ||r||/||r_0|| = 1.86902e-06
# Eisenstat-Walker rtol = 0.000503659
# Newton iteration  7 : ||r|| = 1.27266e-10, ||r||/||r_0|| = 9.09557e-10
# Newton iteration  0 : ||r|| = 0.00460617
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00259398, ||r||/||r_0|| = 0.563152
# Eisenstat-Walker rtol = 0.394915
# Newton iteration  2 : ||r|| = 0.00102997, ||r||/||r_0|| = 0.223605
# Eisenstat-Walker rtol = 0.224355
# Newton iteration  3 : ||r|| = 0.000248324, ||r||/||r_0|| = 0.0539111
# Eisenstat-Walker rtol = 0.100086
# Newton iteration  4 : ||r|| = 2.64708e-05, ||r||/||r_0|| = 0.00574681
# Eisenstat-Walker rtol = 0.0267217
# Newton iteration  5 : ||r|| = 6.93432e-07, ||r||/||r_0|| = 0.000150544
# Eisenstat-Walker rtol = 0.00275838
# Newton iteration  6 : ||r|| = 1.83777e-09, ||r||/||r_0|| = 3.98979e-07
# Eisenstat-Walker rtol = 6.77313e-05
# Newton iteration  7 : ||r|| = 1.88618e-13, ||r||/||r_0|| = 4.09489e-11
# Newton iteration  0 : ||r|| = 0.0166903
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00994164, ||r||/||r_0|| = 0.595653
# Eisenstat-Walker rtol = 0.432445
# Newton iteration  2 : ||r|| = 0.00372015, ||r||/||r_0|| = 0.222892
# Eisenstat-Walker rtol = 0.257587
# Newton iteration  3 : ||r|| = 0.00095358, ||r||/||r_0|| = 0.0571336
# Eisenstat-Walker rtol = 0.111392
# Newton iteration  4 : ||r|| = 0.000177693, ||r||/||r_0|| = 0.0106465
# Eisenstat-Walker rtol = 0.0659696
# Newton iteration  5 : ||r|| = 1.36364e-05, ||r||/||r_0|| = 0.000817022
# Eisenstat-Walker rtol = 0.0157014
# Newton iteration  6 : ||r|| = 2.11793e-07, ||r||/||r_0|| = 1.26896e-05
# Eisenstat-Walker rtol = 0.00118392
# Newton iteration  7 : ||r|| = 2.47129e-10, ||r||/||r_0|| = 1.48067e-08
# Eisenstat-Walker rtol = 1.79608e-05
# Newton iteration  8 : ||r|| = 1.33909e-13, ||r||/||r_0|| = 8.02316e-12
# Newton iteration  0 : ||r|| = 0.102379
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.0559848, ||r||/||r_0|| = 0.546838
# Eisenstat-Walker rtol = 0.376571
# Newton iteration  2 : ||r|| = 0.0206112, ||r||/||r_0|| = 0.201323
# Eisenstat-Walker rtol = 0.205923
# Newton iteration  3 : ||r|| = 0.00417959, ||r||/||r_0|| = 0.0408247
# Eisenstat-Walker rtol = 0.0step 16, t = 48.0, EE = 0.0120549, KE = 0.0116941, dTE = -0.00863195
# step 17, t = 51.0, EE = 0.0140331, KE = 0.00951082, dTE = -0.00883704
# 756399
# Newton iteration  4 : ||r|| = 0.000407487, ||r||/||r_0|| = 0.00398018
# Eisenstat-Walker rtol = 0.0231278
# Newton iteration  5 : ||r|| = 1.94571e-05, ||r||/||r_0|| = 0.000190049
# Eisenstat-Walker rtol = 0.00728648
# Newton iteration  6 : ||r|| = 1.65721e-07, ||r||/||r_0|| = 1.6187e-06
# Eisenstat-Walker rtol = 0.000447875
# Newton iteration  7 : ||r|| = 7.20709e-11, ||r||/||r_0|| = 7.03961e-10
# Newton iteration  0 : ||r|| = 0.00670276
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00284811, ||r||/||r_0|| = 0.424917
# Eisenstat-Walker rtol = 0.325779
# Newton iteration  2 : ||r|| = 0.0008954, ||r||/||r_0|| = 0.133587
# Eisenstat-Walker rtol = 0.16289
# Newton iteration  3 : ||r|| = 0.00023452, ||r||/||r_0|| = 0.0349886
# Eisenstat-Walker rtol = 0.114437
# Newton iteration  4 : ||r|| = 3.13608e-05, ||r||/||r_0|| = 0.00467879
# Eisenstat-Walker rtol = 0.0385633
# Newton iteration  5 : ||r|| = 1.19071e-06, ||r||/||r_0|| = 0.000177644
# Eisenstat-Walker rtol = 0.00502863
# Newton iteration  6 : ||r|| = 6.04803e-09, ||r||/||r_0|| = 9.02319e-07
# Eisenstat-Walker rtol = 0.000194053
# Newton iteration  7 : ||r|| = 1.10967e-12, ||r||/||r_0|| = 1.65555e-10
# Newton iteration  0 : ||r|| = 0.00770271
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00478933, ||r||/||r_0|| = 0.621772
# Eisenstat-Walker rtol = 0.463541
# Newton iteration  2 : ||r|| = 0.00207373, ||r||/||r_0|| = 0.269221
# Eisenstat-Walker rtol = 0.288217
# Newton iteration  3 : ||r|| = 0.000596932, ||r||/||r_0|| = 0.0774964
# Eisenstat-Walker rtol = 0.1336
# Newton iteration  4 : ||r|| = 8.78165e-05, ||r||/||r_0|| = 0.0114007
# Eisenstat-Walker rtol = 0.0450019
# Newton iteration  5 : ||r|| = 4.00113e-06, ||r||/||r_0|| = 0.000519444
# Eisenstat-Walker rtol = 0.00675428
# Newton iteration  6 : ||r|| = 2.68068e-08, ||r||/||r_0|| = 3.48017e-06
# Eisenstat-Walker rtol = 0.000303735
# Newton iteration  7 : ||r|| = 8.18355e-12, ||r||/||r_0|| = 1.06242e-09
# Newton iteration  0 : ||r|| = 0.0585577
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.0313835, ||r||/||r_0|| = 0.535942
# Eisenstat-Walker rtol = 0.364505
# Newton iteration  2 : ||r|| = 0.00862213, ||r||/||r_0|| = 0.147242
# Eisenstat-Walker rtol = 0.195354
# Newton iteration  3 : ||r|| = 0.00165532, ||r||/||r_0|| = 0.0282682
# Eisenstat-Walker rtol = 0.0692312
# Newton iteration  4 : ||r|| = 0.000360238, ||r||/||r_0|| = 0.00615184
# Eisenstat-Walker rtol = 0.0847984
# Newton iteration  5 : ||r|| = 3.61707e-05, ||r||/||r_0|| = 0.000617694
# Eisenstat-Walker rtol = 0.0242565
# Newton iteration  6 : ||r|| = 8.88705e-07, ||r||/||r_0|| = 1.51766e-05
# Eisenstat-Walker rtol = 0.00248664
# Newton iteration  7 : ||r|| = 2.05599e-09, ||r||/||r_0|| = 3.51105e-08
# Eisenstat-Walker rtol = 5.43611e-05
# Newton iteration  8 : ||r|| = 1.72174e-13, ||r||/||r_0|| = 2.94024e-12
# Newton iteration  0 : ||r|| = 0.00624895
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00306561, ||r||/||r_0|| = 0.49058
# Eisenstat-Walker rtol = 0.325779
# Newton iteration  2 : ||r|| = 0.000916629, ||r||/||r_0|| = 0.146685
# Eisenstat-Walker rtol = 0.16289
# Newton iteration  3 : ||r|| = 0.000165275, ||r||/||r_0|| = 0.0264484
# Eisenstat-Walker rtol = 0.0625465
# Newton iteration  4 : ||r|| = 1.10673e-05, ||r||/||r_0|| = 0.00177106
# Eisenstat-Walker rtol = 0.0125939
# Newton iteration  5 : ||r|| = 1.41453e-07, ||r||/||r_0|| = 2.26362e-05
# Eisenstat-Walker rtol = 0.000863711
# Newton iteration  6 : ||r|| = 1.18289e-10, ||r||/||r_0|| = 1.89295e-08
# Eisenstat-Walker rtol = 1.04769e-05
# Newton iteration  7 : ||r|| = 1.37488e-13, ||r||/||r_0|| = 2.20018e-11
# Newton iteration  0 : ||r|| = 0.00421239
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00254309, ||r||/||r_0|| = 0.603717
# Eisenstat-Walker rtol = 0.441958
# Newton iteration  2 : ||r|| = 0.00105354, ||r||/||r_0|| = 0.250106
# Eisenstat-Walker rtol = 0.266818
# Newton iteration  3 : ||r|| = 0.000284958, ||r||/||r_0|| = 0.0676475
# Eisenstat-Walker rtol = 0.120549
# Newton iteration  4 : ||r|| = 3.4091e-05, ||r||/||r_0|| = 0.00809302
# Eisenstat-Walker rtol = 0.0322065
# Newton iteration  5 : ||r|| = 1.09317e-06, ||r||/||r_0|| = 0.000259512
# Eisenstat-Walker rtol =step 18, t = 54.0, EE = 0.0153475, KE = 0.00807129, dTE = -0.00896219
# step 19, t = 57.0, EE = 0.0159471, KE = 0.0073664, dTE = -0.00906746
#  0.00382589
# Newton iteration  6 : ||r|| = 4.06358e-09, ||r||/||r_0|| = 9.64674e-07
# Eisenstat-Walker rtol = 0.000117095
# Newton iteration  7 : ||r|| = 4.95051e-13, ||r||/||r_0|| = 1.17523e-10
# Newton iteration  0 : ||r|| = 0.0295991
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.0162126, ||r||/||r_0|| = 0.547739
# Eisenstat-Walker rtol = 0.377575
# Newton iteration  2 : ||r|| = 0.00476754, ||r||/||r_0|| = 0.16107
# Eisenstat-Walker rtol = 0.206812
# Newton iteration  3 : ||r|| = 0.000962149, ||r||/||r_0|| = 0.032506
# Eisenstat-Walker rtol = 0.0750555
# Newton iteration  4 : ||r|| = 9.88792e-05, ||r||/||r_0|| = 0.00334061
# Eisenstat-Walker rtol = 0.025186
# Newton iteration  5 : ||r|| = 2.72141e-06, ||r||/||r_0|| = 9.19423e-05
# Eisenstat-Walker rtol = 0.00298789
# Newton iteration  6 : ||r|| = 8.05837e-09, ||r||/||r_0|| = 2.7225e-07
# Eisenstat-Walker rtol = 8.10447e-05
# Newton iteration  7 : ||r|| = 6.36845e-13, ||r||/||r_0|| = 2.15157e-11
# Newton iteration  0 : ||r|| = 0.00310816
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00178273, ||r||/||r_0|| = 0.573566
# Eisenstat-Walker rtol = 0.406799
# Newton iteration  2 : ||r|| = 0.000638911, ||r||/||r_0|| = 0.205559
# Eisenstat-Walker rtol = 0.233326
# Newton iteration  3 : ||r|| = 0.000146765, ||r||/||r_0|| = 0.0472193
# Eisenstat-Walker rtol = 0.092549
# Newton iteration  4 : ||r|| = 1.32515e-05, ||r||/||r_0|| = 0.00426346
# Eisenstat-Walker rtol = 0.0204265
# Newton iteration  5 : ||r|| = 2.69981e-07, ||r||/||r_0|| = 8.68621e-05
# Eisenstat-Walker rtol = 0.0018366
# Newton iteration  6 : ||r|| = 4.83599e-10, ||r||/||r_0|| = 1.5559e-07
# Eisenstat-Walker rtol = 3.59341e-05
# Newton iteration  7 : ||r|| = 1.38635e-13, ||r||/||r_0|| = 4.46037e-11
# Newton iteration  0 : ||r|| = 0.00359613
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00216936, ||r||/||r_0|| = 0.603249
# Eisenstat-Walker rtol = 0.441404
# Newton iteration  2 : ||r|| = 0.000916768, ||r||/||r_0|| = 0.254932
# Eisenstat-Walker rtol = 0.266276
# Newton iteration  3 : ||r|| = 0.000253127, ||r||/||r_0|| = 0.0703886
# Eisenstat-Walker rtol = 0.124637
# Newton iteration  4 : ||r|| = 3.09817e-05, ||r||/||r_0|| = 0.00861528
# Eisenstat-Walker rtol = 0.0334177
# Newton iteration  5 : ||r|| = 9.8857e-07, ||r||/||r_0|| = 0.000274898
# Eisenstat-Walker rtol = 0.00379544
# Newton iteration  6 : ||r|| = 3.72562e-09, ||r||/||r_0|| = 1.03601e-06
# Eisenstat-Walker rtol = 0.000119728
# Newton iteration  7 : ||r|| = 4.57478e-13, ||r||/||r_0|| = 1.27214e-10
# Newton iteration  0 : ||r|| = 0.0193152
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.01154, ||r||/||r_0|| = 0.597457
# Eisenstat-Walker rtol = 0.434567
# Newton iteration  2 : ||r|| = 0.00330289, ||r||/||r_0|| = 0.170999
# Eisenstat-Walker rtol = 0.259635
# Newton iteration  3 : ||r|| = 0.00083803, ||r||/||r_0|| = 0.043387
# Eisenstat-Walker rtol = 0.112829
# Newton iteration  4 : ||r|| = 0.000116589, ||r||/||r_0|| = 0.00603614
# Eisenstat-Walker rtol = 0.0411142
# Newton iteration  5 : ||r|| = 5.49598e-06, ||r||/||r_0|| = 0.000284541
# Eisenstat-Walker rtol = 0.00713663
# Newton iteration  6 : ||r|| = 3.90332e-08, ||r||/||r_0|| = 2.02085e-06
# Eisenstat-Walker rtol = 0.000333792
# Newton iteration  7 : ||r|| = 1.26734e-11, ||r||/||r_0|| = 6.56136e-10
# Newton iteration  0 : ||r|| = 0.00264427
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00158986, ||r||/||r_0|| = 0.601247
# Eisenstat-Walker rtol = 0.439036
# Newton iteration  2 : ||r|| = 0.000634707, ||r||/||r_0|| = 0.240031
# Eisenstat-Walker rtol = 0.263969
# Newton iteration  3 : ||r|| = 0.000162203, ||r||/||r_0|| = 0.0613413
# Eisenstat-Walker rtol = 0.115892
# Newton iteration  4 : ||r|| = 1.80255e-05, ||r||/||r_0|| = 0.00681683
# Eisenstat-Walker rtol = 0.0285838
# Newton iteration  5 : ||r|| = 5.02125e-07, ||r||/||r_0|| = 0.000189892
# Eisenstat-Walker rtol = 0.00304672
# Newton iteration  6 : ||r|| = 1.48025e-09, ||r||/||r_0|| = 5.59795e-07
# Eisenstat-Walker rtol = 8.04642e-05
# Newton iteration  7 : ||r|| = 1.80381e-13, ||r||/||r_0|| = 6.8216e-11
# Newton iteration  0 : ||r|| = 0.00404165
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.0023759, ||r||/||r_0||step 20, t = 60.0, EE = 0.016395, KE = 0.00682771, dTE = -0.00915828
# step 21, t = 63.0, EE = 0.0163833, KE = 0.00677779, dTE = -0.00921991
#  = 0.587854
# Eisenstat-Walker rtol = 0.423322
# Newton iteration  2 : ||r|| = 0.000923258, ||r||/||r_0|| = 0.228436
# Eisenstat-Walker rtol = 0.248852
# Newton iteration  3 : ||r|| = 0.000215679, ||r||/||r_0|| = 0.053364
# Eisenstat-Walker rtol = 0.105344
# Newton iteration  4 : ||r|| = 2.29716e-05, ||r||/||r_0|| = 0.00568371
# Eisenstat-Walker rtol = 0.0266854
# Newton iteration  5 : ||r|| = 6.0665e-07, ||r||/||r_0|| = 0.0001501
# Eisenstat-Walker rtol = 0.00279469
# Newton iteration  6 : ||r|| = 1.68132e-09, ||r||/||r_0|| = 4.15997e-07
# Eisenstat-Walker rtol = 7.28148e-05
# Newton iteration  7 : ||r|| = 1.8132e-13, ||r||/||r_0|| = 4.48629e-11
# Newton iteration  0 : ||r|| = 0.0180251
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.0111458, ||r||/||r_0|| = 0.618348
# Eisenstat-Walker rtol = 0.459418
# Newton iteration  2 : ||r|| = 0.00316784, ||r||/||r_0|| = 0.175746
# Eisenstat-Walker rtol = 0.28408
# Newton iteration  3 : ||r|| = 0.000896698, ||r||/||r_0|| = 0.0497471
# Eisenstat-Walker rtol = 0.130512
# Newton iteration  4 : ||r|| = 0.000115362, ||r||/||r_0|| = 0.00640004
# Eisenstat-Walker rtol = 0.0362246
# Newton iteration  5 : ||r|| = 4.21358e-06, ||r||/||r_0|| = 0.000233761
# Eisenstat-Walker rtol = 0.00472303
# Newton iteration  6 : ||r|| = 1.96897e-08, ||r||/||r_0|| = 1.09235e-06
# Eisenstat-Walker rtol = 0.000169556
# Newton iteration  7 : ||r|| = 3.24819e-12, ||r||/||r_0|| = 1.80203e-10
# Newton iteration  0 : ||r|| = 0.00182415
# Eisenstat-Walker rtol = 0.5
# ...
# Newton iteration  0 : ||r|| = 0.00192587
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00110818, ||r||/||r_0|| = 0.575419
# Eisenstat-Walker rtol = 0.408927
# Newton iteration  2 : ||r|| = 0.000431384, ||r||/||r_0|| = 0.223995
# Eisenstat-Walker rtol = 0.235304
# Newton iteration  3 : ||r|| = 9.97673e-05, ||r||/||r_0|| = 0.0518039
# Eisenstat-Walker rtol = 0.0935689
# Newton iteration  4 : ||r|| = 8.91786e-06, ||r||/||r_0|| = 0.00463057
# Eisenstat-Walker rtol = 0.0200966
# Newton iteration  5 : ||r|| = 1.74439e-07, ||r||/||r_0|| = 9.05768e-05
# Eisenstat-Walker rtol = 0.00171948
# Newton iteration  6 : ||r|| = 2.94982e-10, ||r||/||r_0|| = 1.53168e-07
# Eisenstat-Walker rtol = 3.27383e-05
# Newton iteration  7 : ||r|| = 1.39293e-13, ||r||/||r_0|| = 7.23272e-11
# Newton iteration  0 : ||r|| = 0.00546042
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00331186, ||r||/||r_0|| = 0.606522
# Eisenstat-Walker rtol = 0.445285
# Newton iteration  2 : ||r|| = 0.00133316, ||r||/||r_0|| = 0.24415
# Eisenstat-Walker rtol = 0.270075
# Newton iteration  3 : ||r|| = 0.000349796, ||r||/||r_0|| = 0.0640602
# Eisenstat-Walker rtol = 0.12026
# Newton iteration  4 : ||r|| = 4.31396e-05, ||r||/||r_0|| = 0.00790043
# Eisenstat-Walker rtol = 0.0338305
# Newton iteration  5 : ||r|| = 1.43057e-06, ||r||/||r_0|| = 0.00026199
# Eisenstat-Walker rtol = 0.00403957
# Newton iteration  6 : ||r|| = 5.72136e-09, ||r||/||r_0|| = 1.04779e-06
# Eisenstat-Walker rtol = 0.000131806
# Newton iteration  7 : ||r|| = 7.61008e-13, ||r||/||r_0|| = 1.39368e-10
# Newton iteration  0 : ||r|| = 0.0253437
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.0142812, ||r||/||r_0|| = 0.563499
# Eisenstat-Walker rtol = 0.395309
# Newton iteration  2 : ||r|| = 0.00532829, ||r||/||r_0|| = 0.210241
# Eisenstat-Walker rtol = 0.222757
# Newton iteration  3 : ||r|| = 0.00119425, ||r||/||r_step 94, t = 282.0, EE = 0.0107771, KE = 0.00214022, dTE = -0.0194636
# step 95, t = 285.0, EE = 0.0111514, KE = 0.00171235, dTE = -0.0195172
# 0|| = 0.0471221
# Eisenstat-Walker rtol = 0.0889402
# Newton iteration  4 : ||r|| = 0.000221604, ||r||/||r_0|| = 0.00874396
# Eisenstat-Walker rtol = 0.0655212
# Newton iteration  5 : ||r|| = 1.79015e-05, ||r||/||r_0|| = 0.000706349
# Eisenstat-Walker rtol = 0.0170605
# Newton iteration  6 : ||r|| = 3.00145e-07, ||r||/||r_0|| = 1.1843e-05
# Eisenstat-Walker rtol = 0.00133994
# Newton iteration  7 : ||r|| = 3.98463e-10, ||r||/||r_0|| = 1.57224e-08
# Eisenstat-Walker rtol = 2.21313e-05
# Newton iteration  8 : ||r|| = 1.2993e-13, ||r||/||r_0|| = 5.1267e-12
# Newton iteration  0 : ||r|| = 0.00293263
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00173983, ||r||/||r_0|| = 0.593268
# Eisenstat-Walker rtol = 0.429647
# Newton iteration  2 : ||r|| = 0.000678667, ||r||/||r_0|| = 0.231419
# Eisenstat-Walker rtol = 0.254896
# Newton iteration  3 : ||r|| = 0.000175972, ||r||/||r_0|| = 0.060005
# Eisenstat-Walker rtol = 0.112587
# Newton iteration  4 : ||r|| = 1.94137e-05, ||r||/||r_0|| = 0.00661991
# Eisenstat-Walker rtol = 0.0282487
# Newton iteration  5 : ||r|| = 5.24682e-07, ||r||/||r_0|| = 0.000178912
# Eisenstat-Walker rtol = 0.00290121
# Newton iteration  6 : ||r|| = 1.48262e-09, ||r||/||r_0|| = 5.05562e-07
# Eisenstat-Walker rtol = 7.51362e-05
# Newton iteration  7 : ||r|| = 1.68622e-13, ||r||/||r_0|| = 5.74985e-11
# Newton iteration  0 : ||r|| = 0.00174769
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00104908, ||r||/||r_0|| = 0.600269
# Eisenstat-Walker rtol = 0.437881
# Newton iteration  2 : ||r|| = 0.000434187, ||r||/||r_0|| = 0.248435
# Eisenstat-Walker rtol = 0.262846
# Newton iteration  3 : ||r|| = 0.000122044, ||r||/||r_0|| = 0.0698316
# Eisenstat-Walker rtol = 0.128293
# Newton iteration  4 : ||r|| = 1.53025e-05, ||r||/||r_0|| = 0.00875587
# Eisenstat-Walker rtol = 0.0347483
# Newton iteration  5 : ||r|| = 5.17966e-07, ||r||/||r_0|| = 0.000296373
# Eisenstat-Walker rtol = 0.00417584
# Newton iteration  6 : ||r|| = 2.19601e-09, ||r||/||r_0|| = 1.25652e-06
# Eisenstat-Walker rtol = 0.000144858
# Newton iteration  7 : ||r|| = 3.3888e-13, ||r||/||r_0|| = 1.93902e-10
# Newton iteration  0 : ||r|| = 0.0125011
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00677832, ||r||/||r_0|| = 0.542217
# Eisenstat-Walker rtol = 0.371435
# Newton iteration  2 : ||r|| = 0.0021258, ||r||/||r_0|| = 0.170049
# Eisenstat-Walker rtol = 0.201399
# Newton iteration  3 : ||r|| = 0.000469158, ||r||/||r_0|| = 0.0375293
# Eisenstat-Walker rtol = 0.0867443
# Newton iteration  4 : ||r|| = 4.16171e-05, ||r||/||r_0|| = 0.00332907
# Eisenstat-Walker rtol = 0.0198496
# Newton iteration  5 : ||r|| = 8.2604e-07, ||r||/||r_0|| = 6.60773e-05
# Eisenstat-Walker rtol = 0.00176063
# Newton iteration  6 : ||r|| = 1.46979e-09, ||r||/||r_0|| = 1.17573e-07
# Eisenstat-Walker rtol = 3.55483e-05
# Newton iteration  7 : ||r|| = 1.43025e-13, ||r||/||r_0|| = 1.1441e-11
# Newton iteration  0 : ||r|| = 0.00225334
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00130109, ||r||/||r_0|| = 0.577405
# Eisenstat-Walker rtol = 0.411214
# Newton iteration  2 : ||r|| = 0.000479105, ||r||/||r_0|| = 0.21262
# Eisenstat-Walker rtol = 0.237437
# Newton iteration  3 : ||r|| = 0.000111417, ||r||/||r_0|| = 0.0494454
# Eisenstat-Walker rtol = 0.0944082
# Newton iteration  4 : ||r|| = 1.0406e-05, ||r||/||r_0|| = 0.00461804
# Eisenstat-Walker rtol = 0.0215755
# Newton iteration  5 : ||r|| = 2.1686e-07, ||r||/||r_0|| = 9.62394e-05
# Eisenstat-Walker rtol = 0.00190509
# Newton iteration  6 : ||r|| = 3.89893e-10, ||r||/||r_0|| = 1.73029e-07
# Eisenstat-Walker rtol = 3.61509e-05
# Newton iteration  7 : ||r|| = 1.24804e-13, ||r||/||r_0|| = 5.53864e-11
# Newton iteration  0 : ||r|| = 0.00135988
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.000830185, ||r||/||r_0|| = 0.610483
# Eisenstat-Walker rtol = 0.45
# Newton iteration  2 : ||r|| = 0.000336558, ||r||/||r_0|| = 0.24749
# Eisenstat-Walker rtol = 0.274717
# Newton iteration  3 : ||r|| = 9.46189e-05, ||r||/||r_0|| = 0.0695787
# Eisenstat-Walker rtol = 0.128331
# Newton iteration  4 : ||r|| = 1.13303e-05, ||r||/||r_0|| = 0.0083318
# Eisenstat-Walker rtol = 0.032255
# Newton iteration  5 : ||r|| = 3.57526e-07, ||r||/||r_0step 96, t = 288.0, EE = 0.011534, KE = 0.00129793, dTE = -0.019549
# step 97, t = 291.0, EE = 0.0121611, KE = 0.000643309, dTE = -0.0195765
# || = 0.00026291
# Eisenstat-Walker rtol = 0.0037277
# Newton iteration  6 : ||r|| = 1.27505e-09, ||r||/||r_0|| = 9.37616e-07
# Eisenstat-Walker rtol = 0.000109498
# Newton iteration  7 : ||r|| = 1.92031e-13, ||r||/||r_0|| = 1.41211e-10
# Newton iteration  0 : ||r|| = 0.00505794
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00278308, ||r||/||r_0|| = 0.55024
# Eisenstat-Walker rtol = 0.380369
# Newton iteration  2 : ||r|| = 0.00103318, ||r||/||r_0|| = 0.20427
# Eisenstat-Walker rtol = 0.209294
# Newton iteration  3 : ||r|| = 0.000219875, ||r||/||r_0|| = 0.0434713
# Eisenstat-Walker rtol = 0.0817862
# Newton iteration  4 : ||r|| = 1.78841e-05, ||r||/||r_0|| = 0.00353585
# Eisenstat-Walker rtol = 0.017251
# Newton iteration  5 : ||r|| = 2.96657e-07, ||r||/||r_0|| = 5.86518e-05
# Eisenstat-Walker rtol = 0.00131691
# Newton iteration  6 : ||r|| = 3.82008e-10, ||r||/||r_0|| = 7.55263e-08
# Eisenstat-Walker rtol = 2.10662e-05
# Newton iteration  7 : ||r|| = 1.22298e-13, ||r||/||r_0|| = 2.41794e-11
# Newton iteration  0 : ||r|| = 0.00102494
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.000521093, ||r||/||r_0|| = 0.508413
# Eisenstat-Walker rtol = 0.334694
# Newton iteration  2 : ||r|| = 0.000172609, ||r||/||r_0|| = 0.168409
# Eisenstat-Walker rtol = 0.170163
# Newton iteration  3 : ||r|| = 2.7704e-05, ||r||/||r_0|| = 0.0270299
# Eisenstat-Walker rtol = 0.0518128
# Newton iteration  4 : ||r|| = 1.41262e-06, ||r||/||r_0|| = 0.00137825
# Eisenstat-Walker rtol = 0.00810332
# Newton iteration  5 : ||r|| = 1.13036e-08, ||r||/||r_0|| = 1.10285e-05
# Eisenstat-Walker rtol = 0.000404846
# Newton iteration  6 : ||r|| = 4.51695e-12, ||r||/||r_0|| = 4.40704e-09
# Newton iteration  0 : ||r|| = 0.00124576
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.000686875, ||r||/||r_0|| = 0.551369
# Eisenstat-Walker rtol = 0.381632
# Newton iteration  2 : ||r|| = 0.00025008, ||r||/||r_0|| = 0.200745
# Eisenstat-Walker rtol = 0.21042
# Newton iteration  3 : ||r|| = 5.14714e-05, ||r||/||r_0|| = 0.0413172
# Eisenstat-Walker rtol = 0.0774816
# Newton iteration  4 : ||r|| = 3.69152e-06, ||r||/||r_0|| = 0.00296327
# Eisenstat-Walker rtol = 0.014073
# Newton iteration  5 : ||r|| = 5.146e-08, ||r||/||r_0|| = 4.1308e-05
# Eisenstat-Walker rtol = 0.000993931
# Newton iteration  6 : ||r|| = 5.0044e-11, ||r||/||r_0|| = 4.01714e-08
# Eisenstat-Walker rtol = 1.33749e-05
# Newton iteration  7 : ||r|| = 1.29256e-13, ||r||/||r_0|| = 1.03757e-10
# Newton iteration  0 : ||r|| = 0.00392533
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00235896, ||r||/||r_0|| = 0.600957
# Eisenstat-Walker rtol = 0.438694
# Newton iteration  2 : ||r|| = 0.00101872, ||r||/||r_0|| = 0.259525
# Eisenstat-Walker rtol = 0.263636
# Newton iteration  3 : ||r|| = 0.000262188, ||r||/||r_0|| = 0.0667939
# Eisenstat-Walker rtol = 0.115656
# Newton iteration  4 : ||r|| = 2.93481e-05, ||r||/||r_0|| = 0.0074766
# Eisenstat-Walker rtol = 0.0289199
# Newton iteration  5 : ||r|| = 8.28231e-07, ||r||/||r_0|| = 0.000210996
# Eisenstat-Walker rtol = 0.00311151
# Newton iteration  6 : ||r|| = 2.61659e-09, ||r||/||r_0|| = 6.66591e-07
# Eisenstat-Walker rtol = 9e-05
# Newton iteration  7 : ||r|| = 2.61001e-13, ||r||/||r_0|| = 6.64915e-11
# Newton iteration  0 : ||r|| = 0.00135028
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.000589743, ||r||/||r_0|| = 0.436758
# Eisenstat-Walker rtol = 0.325779
# Newton iteration  2 : ||r|| = 0.000187806, ||r||/||r_0|| = 0.139087
# Eisenstat-Walker rtol = 0.16289
# Newton iteration  3 : ||r|| = 2.87523e-05, ||r||/||r_0|| = 0.0212937
# Eisenstat-Walker rtol = 0.0480004
# Newton iteration  4 : ||r|| = 1.37739e-06, ||r||/||r_0|| = 0.00102008
# Eisenstat-Walker rtol = 0.00732515
# Newton iteration  5 : ||r|| = 9.9121e-09, ||r||/||r_0|| = 7.3408e-06
# Eisenstat-Walker rtol = 0.00034098
# Newton iteration  6 : ||r|| = 3.31987e-12, ||r||/||r_0|| = 2.45866e-09
# Newton iteration  0 : ||r|| = 0.00135188
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.000603499, ||r||/||r_0|| = 0.446416
# Eisenstat-Walker rtol = 0.325779
# Newton iteration  2 : ||r|| = 0.000187836, ||r||/||r_0|| = 0.138945
# Eisenstat-Walker rtol = 0.16289
# Newton iteration  3 : ||step 98, t = 294.0, EE = 0.0124972, KE = 0.000290531, dTE = -0.0195932
# step 99, t = 297.0, EE = 0.0122453, KE = 0.000526822, dTE = -0.0196089
# r|| = 2.83773e-05, ||r||/||r_0|| = 0.020991
# Eisenstat-Walker rtol = 0.0469789
# Newton iteration  4 : ||r|| = 1.32671e-06, ||r||/||r_0|| = 0.000981388
# Eisenstat-Walker rtol = 0.0070421
# Newton iteration  5 : ||r|| = 8.83892e-09, ||r||/||r_0|| = 6.53827e-06
# Eisenstat-Walker rtol = 0.000300986
# Newton iteration  6 : ||r|| = 2.64276e-12, ||r||/||r_0|| = 1.95488e-09
# Newton iteration  0 : ||r|| = 0.00263584
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00158776, ||r||/||r_0|| = 0.602371
# Eisenstat-Walker rtol = 0.440365
# Newton iteration  2 : ||r|| = 0.000633677, ||r||/||r_0|| = 0.240408
# Eisenstat-Walker rtol = 0.265263
# Newton iteration  3 : ||r|| = 0.000163068, ||r||/||r_0|| = 0.0618657
# Eisenstat-Walker rtol = 0.116813
# Newton iteration  4 : ||r|| = 1.93164e-05, ||r||/||r_0|| = 0.00732834
# Eisenstat-Walker rtol = 0.0316943
# Newton iteration  5 : ||r|| = 6.0497e-07, ||r||/||r_0|| = 0.000229516
# Eisenstat-Walker rtol = 0.0036827
# Newton iteration  6 : ||r|| = 2.21583e-09, ||r||/||r_0|| = 8.40653e-07
# Eisenstat-Walker rtol = 0.000114327
# Newton iteration  7 : ||r|| = 2.77935e-13, ||r||/||r_0|| = 1.05444e-10
# Newton iteration  0 : ||r|| = 0.00126925
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.000552334, ||r||/||r_0|| = 0.435165
# Eisenstat-Walker rtol = 0.325779
# Newton iteration  2 : ||r|| = 0.000182525, ||r||/||r_0|| = 0.143805
# Eisenstat-Walker rtol = 0.166694
# Newton iteration  3 : ||r|| = 2.9282e-05, ||r||/||r_0|| = 0.0230702
# Eisenstat-Walker rtol = 0.0517744
# Newton iteration  4 : ||r|| = 1.52454e-06, ||r||/||r_0|| = 0.00120113
# Eisenstat-Walker rtol = 0.00838133
# Newton iteration  5 : ||r|| = 1.25457e-08, ||r||/||r_0|| = 9.88429e-06
# Eisenstat-Walker rtol = 0.00042362
# Newton iteration  6 : ||r|| = 5.30542e-12, ||r||/||r_0|| = 4.17995e-09
# Newton iteration  0 : ||r|| = 0.00111005
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.000541839, ||r||/||r_0|| = 0.488121
# Eisenstat-Walker rtol = 0.325779
# Newton iteration  2 : ||r|| = 0.00016391, ||r||/||r_0|| = 0.14766
# Eisenstat-Walker rtol = 0.16289
# Newton iteration  3 : ||r|| = 2.48436e-05, ||r||/||r_0|| = 0.0223806
# Eisenstat-Walker rtol = 0.0472279
# Newton iteration  4 : ||r|| = 1.14986e-06, ||r||/||r_0|| = 0.00103586
# Eisenstat-Walker rtol = 0.0069282
# Newton iteration  5 : ||r|| = 7.80545e-09, ||r||/||r_0|| = 7.03162e-06
# Eisenstat-Walker rtol = 0.000310244
# Newton iteration  6 : ||r|| = 2.37169e-12, ||r||/||r_0|| = 2.13656e-09
# Newton iteration  0 : ||r|| = 0.00197854
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00119781, ||r||/||r_0|| = 0.605399
# Eisenstat-Walker rtol = 0.443952
# Newton iteration  2 : ||r|| = 0.000454543, ||r||/||r_0|| = 0.229737
# Eisenstat-Walker rtol = 0.268768
# Newton iteration  3 : ||r|| = 0.00012016, ||r||/||r_0|| = 0.0607318
# Eisenstat-Walker rtol = 0.11932
# Newton iteration  4 : ||r|| = 1.42474e-05, ||r||/||r_0|| = 0.00720094
# Eisenstat-Walker rtol = 0.0317437
# Newton iteration  5 : ||r|| = 4.41298e-07, ||r||/||r_0|| = 0.000223042
# Eisenstat-Walker rtol = 0.00361729
# Newton iteration  6 : ||r|| = 1.57222e-09, ||r||/||r_0|| = 7.94637e-07
# Eisenstat-Walker rtol = 0.00010932
# Newton iteration  7 : ||r|| = 2.1689e-13, ||r||/||r_0|| = 1.09621e-10
# Newton iteration  0 : ||r|| = 0.00081435
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.000400915, ||r||/||r_0|| = 0.492312
# Eisenstat-Walker rtol = 0.325779
# Newton iteration  2 : ||r|| = 0.000122078, ||r||/||r_0|| = 0.149908
# Eisenstat-Walker rtol = 0.16289
# Newton iteration  3 : ||r|| = 1.8963e-05, ||r||/||r_0|| = 0.023286
# Eisenstat-Walker rtol = 0.0491416
# Newton iteration  4 : ||r|| = 9.03155e-07, ||r||/||r_0|| = 0.00110905
# Eisenstat-Walker rtol = 0.00725647
# Newton iteration  5 : ||r|| = 6.59671e-09, ||r||/||r_0|| = 8.10058e-06
# Eisenstat-Walker rtol = 0.000349281
# Newton iteration  6 : ||r|| = 2.2872e-12, ||r||/||r_0|| = 2.80862e-09
# Newton iteration  0 : ||r|| = 0.000902905
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.000538535, ||r||/||r_0|| = 0.596447
# Eisenstat-Walker rtol = 0.433379
# Newton iteration  2 : ||r|| = 0.00019869, ||r||/||r_0|| = 0.220057
# Eisenstat-Walker rtol Creating DMD with energy fraction: 0.9999
# = 0.258488
# Newton iteration  3 : ||r|| = 5.36622e-05, ||r||/||r_0|| = 0.0594328
# Eisenstat-Walker rtol = 0.120264
# Newton iteration  4 : ||r|| = 6.21616e-06, ||r||/||r_0|| = 0.00688462
# Eisenstat-Walker rtol = 0.0305692
# Newton iteration  5 : ||r|| = 1.84069e-07, ||r||/||r_0|| = 0.000203863
# Eisenstat-Walker rtol = 0.00336331
# Newton iteration  6 : ||r|| = 6.08216e-10, ||r||/||r_0|| = 6.73621e-07
# Eisenstat-Walker rtol = 9.67796e-05
# Newton iteration  7 : ||r|| = 1.44354e-13, ||r||/||r_0|| = 1.59878e-10
# Newton iteration  0 : ||r|| = 0.00342847
# Eisenstat-Walker rtol = 0.5
# Newton iteration  1 : ||r|| = 0.00203276, ||r||/||r_0|| = 0.592907
# Eisenstat-Walker rtol = 0.429225
# Newton iteration  2 : ||r|| = 0.000748613, ||r||/||r_0|| = 0.218352
# Eisenstat-Walker rtol = 0.254491
# Newton iteration  3 : ||r|| = 0.000190075, ||r||/||r_0|| = 0.0554402
# Eisenstat-Walker rtol = 0.109234
# Newton iteration  4 : ||r|| = 1.97939e-05, ||r||/||r_0|| = 0.00577341
# Eisenstat-Walker rtol = 0.0257309
# Newton iteration  5 : ||r|| = 5.02761e-07, ||r||/||r_0|| = 0.000146643
# Eisenstat-Walker rtol = 0.00262398
# Newton iteration  6 : ||r|| = 1.29695e-09, ||r||/||r_0|| = 3.78289e-07
# Eisenstat-Walker rtol = 6.48363e-05
# Newton iteration  7 : ||r|| = 1.59669e-13, ||r||/||r_0|| = 4.65714e-11
# Using 45 basis vectors out of 100.
# step 100, t = 300.0, EE = 0.0119584, KE = 0.000784203, dTE = -0.0196383Using 19 basis vectors out of 100.

# %%
true_solution_v = vx.GetBlock(0)
true_solution_x = vx.GetBlock(1)

# Predict using DMD.
dmd_prediction_timer.Start()
if myid == 0:
    print('Predicting position and velocity using DMD')

curr_window = 0
result_v = dmd_v[curr_window].predict(ts[0]) 
result_x = dmd_x[curr_window].predict(ts[0]) 
initial_dmd_v = mfem.Vector(result_v.getData(), result_v.dim())
initial_dmd_x = mfem.Vector(result_x.getData(), result_x.dim())
v_gf.SetFromTrueDofs(initial_dmd_v)
x_gf.SetFromTrueDofs(initial_dmd_x)
# Out:
# Predicting position and velocity using DMD

# %%
if visit:
    dmd_dc = mfem.VisItDataCollection('DMD_nonlinear_elasticity', pmesh)
    dmd_dc.RegisterField('v',v_gf)
    dmd_dc.RegisterField('x',x_gf)
    dmd_dc.SetCycle(0)
    dmd_dc.SetTime(0.0)
    dmd_dc.Save()

    for i in range(1,len(ts)):
        result_v = dmd_v[curr_window].predict(ts[i]) 
        result_x = dmd_x[curr_window].predict(ts[i]) 
        dmd_solution_v = mfem.Vector(result_v.getData(), result_v.dim())
        dmd_solution_x = mfem.Vector(result_x.getData(), result_x.dim())
        v_gf.SetFromTrueDofs(dmd_solution_v)
        x_gf.SetFromTrueDofs(dmd_solution_x)

        nodes = x_gf
        owns_nodes = 0
        nodes, owns_nodes = pmesh.SwapNodes(nodes, owns_nodes)
        dmd_dc.SetCycle(i)
        dmd_dc.SetTime(ts[i])
        dmd_dc.Save()
        nodes, owns_nodes = pmesh.SwapNodes(nodes, owns_nodes)

        if i % windowNumSamples == 0 and i < len(ts)-1:
            curr_window += 1
else:
    curr_window = len(dmd_v) - 1

result_v = dmd_v[curr_window].predict(t_final) 
result_x = dmd_x[curr_window].predict(t_final) 

dmd_prediction_timer.Stop()

# %%
# Calculate the relative error between the DMD final solution and the true solution.
dmd_solution_v = mfem.Vector(result_v.getData(), result_v.dim())
diff_v = mfem.Vector(true_solution_v.Size())
mfem.subtract_vector(dmd_solution_v, true_solution_v, diff_v)
tot_diff_norm_v = np.sqrt(mfem.InnerProduct(diff_v, diff_v))
tot_true_solution_v_norm = np.sqrt(mfem.InnerProduct(true_solution_v, true_solution_v))

dmd_solution_x = mfem.Vector(result_x.getData(), result_x.dim())
diff_x = mfem.Vector(true_solution_x.Size())
mfem.subtract_vector(dmd_solution_x, true_solution_x, diff_x)
tot_diff_norm_x = np.sqrt(mfem.InnerProduct(diff_x, diff_x))
tot_true_solution_x_norm = np.sqrt(mfem.InnerProduct(true_solution_x, true_solution_x))

if myid == 0:
    print("Relative error of DMD velocity (v) at t_final: %f is %.3E" % (t_final, tot_diff_norm_v / tot_true_solution_v_norm))
    print("Relative error of DMD position (x) at t_final: %f is %.3E" % (t_final, tot_diff_norm_x / tot_true_solution_x_norm))
    print("Elapsed time for solving FOM: %e second\n" % fom_timer.duration)
    print("Elapsed time for training DMD: %e second\n" % dmd_training_timer.duration)
    print("Elapsed time for predicting DMD: %e second\n" % dmd_prediction_timer.duration)
# Out:
# Relative error of DMD velocity (v) at t_final: 300.000000 is 8.589E-01
# Relative error of DMD position (x) at t_final: 300.000000 is 8.903E-01
# Elapsed time for solving FOM: 9.501336e+02 second
#
# Elapsed time for training DMD: 2.410322e+00 second
#
# Elapsed time for predicting DMD: 1.182828e+00 second

# %%
#
# if i translate c++ line-by-line, ti seems the second swap does not work...
#

smyid = '{:0>6d}'.format(myid)
mesh_name = "deformed."+smyid
velo_name = "velocity."+smyid
ee_name = "elastic_energy."+smyid

nodes = x_gf
owns_nodes = 0
nodes, owns_nodes = pmesh.SwapNodes(nodes, owns_nodes)
pmesh.Print(mesh_name, 8)
pmesh.SwapNodes(nodes, owns_nodes)

v_gf.Save(velo_name, 8)
oper.GetElasticEnergyDensity(x_gf, w_gf)
w_gf.Save(ee_name,  8)
