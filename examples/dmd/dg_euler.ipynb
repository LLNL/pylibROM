# %%
import mfem.par as mfem

from dg_euler_common import FE_Evolution, InitialCondition, \
                            RiemannSolver, DomainIntegrator, FaceIntegrator
from mfem.common.arg_parser import ArgParser

from os.path import expanduser, join, dirname
import numpy as np
from numpy import sqrt, pi, cos, sin, hypot, arctan2
from scipy.special import erfc
from ctypes import *

# Equation constant parameters.(using globals to share them with dg_euler_common)
import dg_euler_common
from pylibROM.python_utils.StopWatch import StopWatch
from pylibROM.algo import NonuniformDMD, AdaptiveDMD
from mpi4py import MPI
num_procs = MPI.COMM_WORLD.size
myid = MPI.COMM_WORLD.rank

# %%
args_dict = {
    'mesh': 'periodic-square.mesh',
    'problem' : 1,
    'refine_serial': 0,
    'refine_parallel': 1,
    'order': 3,
    'ode_solver': 4,
    't_final': 2.0,
    'time_step': -0.01,
    'cfl_number': 0.3,
    'visualization': False,
    'visit_datafiles': False,
    'visualization_steps': 50,
    'energy_fraction': 0.9999,
    'rdim': -1,
    'crbf': 0.9,
    'nonunif': False
}

# %%
import argparse

parser = argparse.ArgumentParser(description='dg_euler')

for arg, value in args_dict.items():
    parser.add_argument(f'--{arg}', action='store', default=value, type=type(value), help=f'{arg}')

args = parser.parse_args([])

# %%
# The rest of your script
mesh = args.mesh
ser_ref_levels = args.refine_serial
par_ref_levels = args.refine_parallel
order = args.order
ode_solver_type = args.ode_solver
t_final = args.t_final
dt = args.time_step
cfl = args.cfl_number
visualization = args.visualization
visit = args.visit_datafiles
vis_steps = args.visualization_steps
ef = args.energy_fraction
rdim = args.rdim
crbf = args.crbf
nonunif = args.nonunif

# %%
if myid == 0:
    print("Command Line Options:")
    for arg, value in vars(args).items():
        print(f"{arg}: {value}")

device = mfem.Device('cpu')
if myid == 0:
    device.Print()

dg_euler_common.num_equation = 4
dg_euler_common.specific_heat_ratio = 1.4
dg_euler_common.gas_constant = 1.0
dg_euler_common.problem = args.problem
num_equation = dg_euler_common.num_equation
# Out:
# Command Line Options:
# mesh: periodic-square.mesh
# problem: 1
# refine_serial: 0
# refine_parallel: 1
# order: 3
# ode_solver: 4
# t_final: 2.0
# time_step: -0.01
# cfl_number: 0.3
# visualization: False
# visit_datafiles: False
# visualization_steps: 50
# energy_fraction: 0.9999
# rdim: -1
# crbf: 0.9
# nonunif: False
# Device configuration: cpu
# Memory configuration: host-std

# %%
# 3. Read the mesh from the given mesh file. This example requires a 2D
#    periodic mesh, such as ../data/periodic-square.mesh.
meshfile = expanduser(join(dirname(mesh), '..', 'data', mesh))
mesh = mfem.Mesh(meshfile, 1, 1)
dim = mesh.Dimension()

# 4. Define the ODE solver used for time integration. Several explicit
#    Runge-Kutta methods are available.
ode_solver = None
if ode_solver_type == 1:
    ode_solver = mfem.ForwardEulerSolver()
elif ode_solver_type == 2:
    ode_solver = mfem.RK2Solver(1.0)
elif ode_solver_type == 3:
    ode_solver = mfem.RK3SSolver()
elif ode_solver_type == 4:
    ode_solver = mfem.RK4Solver()
elif ode_solver_type == 6:
    ode_solver = mfem.RK6Solver()
else:
    print("Unknown ODE solver type: " + str(ode_solver_type))
    exit

# %%
# 5. Refine the mesh in serial to increase the resolution. In this example
#    we do 'ser_ref_levels' of uniform refinement, where 'ser_ref_levels' is
#    a command-line parameter.
for lev in range(ser_ref_levels):
    mesh.UniformRefinement()

# %%
# 6. Define a parallel mesh by a partitioning of the serial mesh. Refine
#    this mesh further in parallel to increase the resolution. Once the
#    parallel mesh is defined, the serial mesh can be deleted.

pmesh = mfem.ParMesh(MPI.COMM_WORLD, mesh)
del mesh
for lev in range(par_ref_levels):
    pmesh.UniformRefinement()

# %%
# 7. Define the discontinuous DG finite element space of the given
#    polynomial order on the refined mesh.
fec = mfem.DG_FECollection(order, dim)
# Finite element space for a scalar (thermodynamic quantity)
fes = mfem.ParFiniteElementSpace(pmesh, fec)
# Finite element space for a mesh-dim vector quantity (momentum)
dfes = mfem.ParFiniteElementSpace(pmesh, fec, dim, mfem.Ordering.byNODES)
# Finite element space for all variables together (total thermodynamic state)
vfes = mfem.ParFiniteElementSpace(
    pmesh, fec, num_equation, mfem.Ordering.byNODES)

assert fes.GetOrdering() == mfem.Ordering.byNODES, "Ordering must be byNODES"
glob_size = vfes.GlobalTrueVSize()
if myid == 0:
    print("Number of unknowns: " + str(glob_size))
# Out:
# Number of unknowns: 2304

# %%
# 8. Define the initial conditions, save the corresponding mesh and grid
#    functions to a file. This can be opened with GLVis with the -gc option.
#    The solution u has components {density, x-momentum, y-momentum, energy}.
#    These are stored contiguously in the BlockVector u_block.

offsets = [k*vfes.GetNDofs() for k in range(num_equation+1)]
offsets = mfem.intArray(offsets)
u_block = mfem.BlockVector(offsets)

#  Momentum grid function on dfes for visualization.
mom = mfem.ParGridFunction(dfes, u_block,  offsets[1])

#  Initialize the state.
u0 = InitialCondition(num_equation)
sol = mfem.ParGridFunction(vfes, u_block.GetData())
sol.ProjectCoefficient(u0)

smyid = '{:0>6d}'.format(myid)
pmesh.Print("vortex-mesh."+smyid, 8)
for k in range(num_equation):
    uk = mfem.ParGridFunction(fes, u_block.GetBlock(k).GetData())
    sol_name = "vortex-" + str(k) + "-init."+smyid
    uk.Save(sol_name, 8)

# %%
# 9. Set up the nonlinear form corresponding to the DG discretization of the
#    flux divergence, and assemble the corresponding mass matrix.
Aflux = mfem.MixedBilinearForm(dfes, fes)
Aflux.AddDomainIntegrator(DomainIntegrator(dim))
Aflux.Assemble()

A = mfem.ParNonlinearForm(vfes)
rsolver = RiemannSolver()
ii = FaceIntegrator(rsolver, dim)
A.AddInteriorFaceIntegrator(ii)

# %%
# 10. Define the time-dependent evolution operator describing the ODE
#     right-hand side, and perform time-integration (looping over the time
#     iterations, ti, with a time-step dt).
euler = FE_Evolution(vfes, A, Aflux.SpMat())

if (visualization):
    MPI.COMM_WORLD.Barrier()
    sout = mfem.socketstream("localhost", 19916)
    sout.send_text("parallel " + str(num_procs) + " " + str(myid))
    sout.precision(8)
    sout.send_solution(pmesh, mom)
    sout.send_text("pause")
    sout.flush()
    if myid == 0:
        print("GLVis visualization paused.")
        print(" Press space (in the GLVis window) to resume it.")

# Determine the minimum element size.
my_hmin = 0
if (cfl > 0):
    my_hmin = min([pmesh.GetElementSize(i, 1) for i in range(pmesh.GetNE())])
hmin = MPI.COMM_WORLD.allreduce(my_hmin, op=MPI.MIN)

# initialize timers
fom_timer, dmd_training_timer, dmd_prediction_timer = \
        StopWatch(), StopWatch(), StopWatch()

fom_timer.Start()
t = 0.0
ts = []
euler.SetTime(t)
ode_solver.Init(euler)
fom_timer.Stop()

if (cfl > 0):
    #  Find a safe dt, using a temporary vector. Calling Mult() computes the
    #  maximum char speed at all quadrature points on all faces.
    z = mfem.Vector(A.Width())
    A.Mult(sol, z)
    max_char_speed = MPI.COMM_WORLD.allreduce(dg_euler_common.max_char_speed, op=MPI.MAX) 
    dg_euler_common.max_char_speed = max_char_speed 
    dt = cfl * hmin / dg_euler_common.max_char_speed / (2*order+1)

#- DMD setup
# Initialize dmd_vars = [dmd_dens, dmd_x_mom, dmd_y_mom, dmd_e]
dmd_training_timer.Start()
if nonunif:
    dmd_vars = [NonuniformDMD(u_block.GetBlock(i).Size()) 
                for i in range(4)]
else:
    dmd_vars = [AdaptiveDMD(u_block.GetBlock(i).Size(),dt,'G','LS',crbf) \
                for i in range(4)]
for i in range(4):
    dmd_vars[i].takeSample(u_block.GetBlock(i).GetDataArray(),t)
ts += [t]
dmd_training_timer.Stop()

# Integrate in time.
done = False
ti = 0
while not done:

    fom_timer.Start()

    dt_real = min(dt, t_final - t)
    t, dt_real = ode_solver.Step(sol, t, dt_real)

    if (cfl > 0):
        max_char_speed = MPI.COMM_WORLD.allreduce(
            dg_euler_common.max_char_speed, op=MPI.MAX)
        dg_euler_common.max_char_speed = max_char_speed
        dt = cfl * hmin / dg_euler_common.max_char_speed / (2*order+1)

    ti = ti+1
    done = (t >= t_final - 1e-8*dt)

    fom_timer.Stop()
    
    #- DMD take sample
    dmd_training_timer.Start()
    for i in range(4):
        dmd_vars[i].takeSample(u_block.GetBlock(i).GetDataArray(),t)
    ts.append(t)
    dmd_training_timer.Stop()


    if (done or ti % vis_steps == 0):
        if myid == 0:
            print("time step: " + str(ti) + ", time: " + "{:g}".format(t))
        if (visualization):
            sout.send_text("parallel " + str(num_procs) + " " + str(myid))
            sout.send_solution(pmesh, mom)
            sout.flush()
        if visit:
            visit_dc.SetCycle(ti)
            visit_dc.SetTime(t)
            visit_dc.Save()


if myid == 0:
    print("done")
# Out:
# time step: 50, time: 0.229077
# time step: 100, time: 0.458133
# time step: 150, time: 0.687228
# time step: 200, time: 0.916314
# time step: 250, time: 1.14537
# time step: 300, time: 1.37445
# time step: 350, time: 1.60354
# time step: 400, time: 1.83259
# time step: 437, time: 2
# done

# %%
# 11. Save the final solution. This output can be viewed later using GLVis:
#     "glvis -np 4 -m vortex-mesh -g vortex-1-final".

for k in range(num_equation):
    uk = mfem.ParGridFunction(fes, u_block.GetBlock(k).GetData())
    sol_name = "vortex-" + str(k) + "-final."+smyid
    uk.Save(sol_name, 8)

# %%
# 12. Compute the L2 solution error summed for all components.
if (t_final == 2.0):
    error = sol.ComputeLpError(2., u0)
    if myid == 0:
        print("Solution error: " + "{:g}".format(error))
# Out:
# Solution error: 0.00387366

# %%
# 13. Calculate the DMD modes
if myid==0 and rdim != -1 and ef != -1:
    print('Both rdim and ef are set. ef will be ignored')

dmd_training_timer.Start()

if rdim != -1:
    if myid==0:
        print(f'Creating DMD with rdim: {rdim}')
    for dmd_var in dmd_vars:
        dmd_var.train(rdim)
elif ef != -1:
    if myid == 0:
        print(f'Creating DMD with energy fraction: {ef}')
    for dmd_var in dmd_vars:
        dmd_var.train(ef)

dmd_training_timer.Stop()

true_solution_vars = [u_block.GetBlock(i) for i in range(4)]
# Out:
# Creating DMD with energy fraction: 0.9999
# Number of snapshots is: 438
# Setting desired dt to 0.00457666 to ensure a constant dt given the final sampled time.
# Creating new interpolated sample at: 0
# Creating new interpolated sample at: 0.00457666
# Creating new interpolated sample at: 0.00915332
# Creating new interpolated sample at: 0.01373
# Creating new interpolated sample at: 0.0183066
# Creating new interpolated sample at: 0.0228833
# Creating new interpolated sample at: 0.02746
# Creating new interpolated sample at: 0.0320366
# Creating new interpolated sample at: 0.0366133
# Creating new interpolated sample at: 0.0411899
# Creating new interpolated sample at: 0.0457666
# Creating new interpolated sample at: 0.0503432
# Creating new interpolated sample at: 0.0549199
# Creating new interpolated sample at: 0.0594966
# Creating new interpolated sample at: 0.0640732
# Creating new interpolated sample at: 0.0686499
# Creating new interpolated sample at: 0.0732265
# Creating new interpolated sample at: 0.0778032
# Creating new interpolated sample at: 0.0823799
# Creating new interpolated sample at: 0.0869565
# Creating new interpolated sample at: 0.0915332
# Creating new interpolated sample at: 0.0961098
# Creating new interpolated sample at: 0.100686
# Creating new interpolated sample at: 0.105263
# Creating new interpolated sample at: 0.10984
# Creating new interpolated sample at: 0.114416
# Creating new interpolated sample at: 0.118993
# Creating new interpolated sample at: 0.12357
# Creating new interpolated sample at: 0.128146
# Creating new interpolated sample at: 0.132723
# Creating new interpolated sample at: 0.1373
# Creating new interpolated sample at: 0.141876
# Creating new interpolated sample at: 0.146453
# Creating new interpolated sample at: 0.15103
# Creating new interpolated sample at: 0.155606
# Creating new interpolated sample at: 0.160183
# Creating new interpolated sample at: 0.16476
# Creating new interpolated sample at: 0.169336
# Creating new interpolated sample at: 0.173913
# Creating new interpolated sample at: 0.17849
# Creating new interpolated sample at: 0.183066
# Creating new interpolated sample at: 0.187643
# Creating new interpolated sample at: 0.19222
# Creating new interpolated sample at: 0.196796
# Creating new interpolated sample at: 0.201373
# Creating new interpolated sample at: 0.20595
# Creating new interpolated sample at: 0.210526
# Creating new interpolated sample at: 0.215103
# Creating new interpolated sample at: 0.21968
# Creating new interpolated sample at: 0.224256
# Creating new interpolated sample at: 0.228833
# Creating new interpolated sample at: 0.23341
# Creating new interpolated sample at: 0.237986
# Creating new interpolated sample at: 0.242563
# Creating new interpolated sample at: 0.24714
# Creating new interpolated sample at: 0.251716
# Creating new interpolated sample at: 0.256293
# Creating new interpolated sample at: 0.26087
# Creating new interpolated sample at: 0.265446
# Creating new interpolated sample at: 0.270023
# Creating new interpolated sample at: 0.2746
# Creating new interpolated sample at: 0.279176
# Creating new interpolated sample at: 0.283753
# Creating new interpolated sample at: 0.28833
# Creating new interpolated sample at: 0.292906
# Creating new interpolated sample at: 0.297483
# Creating new interpolated sample at: 0.302059
# Creating new interpolated sample at: 0.306636
# Creating new interpolated sample at: 0.311213
# Creating new interpolated sample at: 0.315789
# Creating new interpolated sample at: 0.320366
# Creating new interpolated sample at: 0.324943
# Creating new interpolated sample at: 0.329519
# Creating new interpolated sample at: 0.334096
# Creating new interpolated sample at: 0.338673
# Creating new interpolated sample at: 0.343249
# Creating new interpolated sample at: 0.347826
# Creating new interpolated sample at: 0.352403
# Creating new interpolated sample at: 0.356979
# Creating new interpolated sample at: 0.361556
# Creating new interpolated sample at: 0.366133
# Creating new interpolated sample at: 0.370709
# Creating new interpolated sample at: 0.375286
# Creating new interpolated sample at: 0.379863
# Creating new interpolated sample at: 0.384439
# Creating new interpolated sample at: 0.389016
# Creating new interpolated sample at: 0.393593
# Creating new interpolated sample at: 0.398169
# Creating new interpolated sample at: 0.402746
# Creating new interpolated sample at: 0.407323
# Creating new interpolated sample at: 0.411899
# Creating new interpolated sample at: 0.416476
# Creating new interpolated sample at: 0.421053
# Creating new interpolated sample at: 0.425629
# Creating new interpolated sample at: 0.430206
# Creating new interpolated sample at: 0.434783
# Creating new interpolated sample at: 0.439359
# Creating new interpolated sample at: 0.443936
# Creating new interpolated sample at: 0.448513
# Creating new interpolated sample at: 0.453089
# Creating new interpolated sample at: 0.457666
# Creating new interpolated sample at: 0.462243
# Creating new interpolated sample at: 0.466819
# Creating new interpolated sample at: 0.471396
# Creating new interpolated sample at: 0.475973
# Creating new interpolated sample at: 0.480549
# Creating new interpolated sample at: 0.485126
# Creating new interpolated sample at: 0.489703
# Creating new interpolated sample at: 0.494279
# Creating new interpolated sample at: 0.498856
# Creating new interpolated sample at: 0.503432
# Creating new interpolated sample at: 0.508009
# Creating new interpolated sample at: 0.512586
# Creating new interpolated sample at: 0.517162
# Creating new interpolated sample at: 0.521739
# Creating new interpolated sample at: 0.526316
# Creating new interpolated sample at: 0.530892
# Creating new interpolated sample at: 0.535469
# Creating new interpolated sample at: 0.540046
# Creating new interpolated sample at: 0.544622
# Creating new interpolated sample at: 0.549199
# Creating new interpolated sample at: 0.553776
# Creating new interpolated sample at: 0.558352
# Creating new interpolated sample at: 0.562929
# Creating new interpolated sample at: 0.567506
# Creating new interpolated sample at: 0.572082
# Creating new interpolated sample at: 0.576659
# Creating new interpolated sample at: 0.581236
# Creating new interpolated sample at: 0.585812
# Creating new interpolated sample at: 0.590389
# Creating new interpolated sample at: 0.594966
# Creating new interpolated sample at: 0.599542
# Creating new interpolated sample at: 0.604119
# Creating new interpolated sample at: 0.608696
# Creating new interpolated sample at: 0.613272
# Creating new interpolated sample at: 0.617849
# Creating new interpolated sample at: 0.622426
# Creating new interpolated sample at: 0.627002
# Creating new interpolated sample at: 0.631579
# Creating new interpolated sample at: 0.636156
# Creating new interpolated sample at: 0.640732
# Creating new interpolated sample at: 0.645309
# Creating new interpolated sample at: 0.649886
# Creating new interpolated sample at: 0.654462
# Creating new interpolated sample at: 0.659039
# Creating new interpolated sample at: 0.663616
# Creating new interpolated sample at: 0.668192
# Creating new interpolated sample at: 0.672769
# Creating new interpolated sample at: 0.677346
# Creating new interpolated sample at: 0.681922
# Creating new interpolated sample at: 0.686499
# Creating new interpolated sample at: 0.691076
# Creating new interpolated sample at: 0.695652
# Creating new interpolated sample at: 0.700229
# Creating new interpolated sample at: 0.704805
# Creating new interpolated sample at: 0.709382
# Creating new interpolated sample at: 0.713959
# Creating new interpolated sample at: 0.718535
# Creating new interpolated sample at: 0.723112
# Creating new interpolated sample at: 0.727689
# Creating new interpolated sample at: 0.732265
# Creating new interpolated sample at: 0.736842
# Creating new interpolated sample at: 0.741419
# Creating new interpolated sample at: 0.745995
# Creating new interpolated sample at: 0.750572
# Creating new interpolated sample at: 0.755149
# Creating new interpolated sample at: 0.759725
# Creating new interpolated sample at: 0.764302
# Creating new interpolated sample at: 0.768879
# Creating new interpolated sample at: 0.773455
# Creating new interpolated sample at: 0.778032
# Creating new interpolated sample at: 0.782609
# Creating new interpolated sample at: 0.787185
# Creating new interpolated sample at: 0.791762
# Creating new interpolated sample at: 0.796339
# Creating new interpolated sample at: 0.800915
# Creating new interpolated sample at: 0.805492
# Creating new interpolated sample at: 0.810069
# Creating new interpolated sample at: 0.814645
# Creating new interpolated sample at: 0.819222
# Creating new interpolated sample at: 0.823799
# Creating new interpolated sample at: 0.828375
# Creating new interpolated sample at: 0.832952
# Creating new interpolated sample at: 0.837529
# Creating new interpolated sample at: 0.842105
# Creating new interpolated sample at: 0.846682
# Creating new interpolated sample at: 0.851259
# Creating new interpolated sample at: 0.855835
# Creating new interpolated sample at: 0.860412
# Creating new interpolated sample at: 0.864989
# Creating new interpolated sample at: 0.869565
# Creating new interpolated sample at: 0.874142
# Creating new interpolated sample at: 0.878719
# Creating new interpolated sample at: 0.883295
# Creating new interpolated sample at: 0.887872
# Creating new interpolated sample at: 0.892449
# Creating new interpolated sample at: 0.897025
# Creating new interpolated sample at: 0.901602
# Creating new interpolated sample at: 0.906178
# Creating new interpolated sample at: 0.910755
# Creating new interpolated sample at: 0.915332
# Creating new interpolated sample at: 0.919908
# Creating new interpolated sample at: 0.924485
# Creating new interpolated sample at: 0.929062
# Creating new interpolated sample at: 0.933638
# Creating new interpolated sample at: 0.938215
# Creating new interpolated sample at: 0.942792
# Creating new interpolated sample at: 0.947368
# Creating new interpolated sample at: 0.951945
# Creating new interpolated sample at: 0.956522
# Creating new interpolated sample at: 0.961098
# Creating new interpolated sample at: 0.965675
# Creating new interpolated sample at: 0.970252
# Creating new interpolated sample at: 0.974828
# Creating new interpolated sample at: 0.979405
# Creating new interpolated sample at: 0.983982
# Creating new interpolated sample at: 0.988558
# Creating new interpolated sample at: 0.993135
# Creating new interpolated sample at: 0.997712
# Creating new interpolated sample at: 1.00229
# Creating new interpolated sample at: 1.00686
# Creating new interpolated sample at: 1.01144
# Creating new interpolated sample at: 1.01602
# Creating new interpolated sample at: 1.02059
# Creating new interpolated sample at: 1.02517
# Creating new interpolated sample at: 1.02975
# Creating new interpolated sample at: 1.03432
# Creating new interpolated sample at: 1.0389
# Creating new interpolated sample at: 1.04348
# Creating new interpolated sample at: 1.04805
# Creating new interpolated sample at: 1.05263
# Creating new interpolated sample at: 1.05721
# Creating new interpolated sample at: 1.06178
# Creating new interpolated sample at: 1.06636
# Creating new interpolated sample at: 1.07094
# Creating new interpolated sample at: 1.07551
# Creating new interpolated sample at: 1.08009
# Creating new interpolated sample at: 1.08467
# Creating new interpolated sample at: 1.08924
# Creating new interpolated sample at: 1.09382
# Creating new interpolated sample at: 1.0984
# Creating new interpolated sample at: 1.10297
# Creating new interpolated sample at: 1.10755
# Creating new interpolated sample at: 1.11213
# Creating new interpolated sample at: 1.1167
# Creating new interpolated sample at: 1.12128
# Creating new interpolated sample at: 1.12586
# Creating new interpolated sample at: 1.13043
# Creating new interpolated sample at: 1.13501
# Creating new interpolated sample at: 1.13959
# Creating new interpolated sample at: 1.14416
# Creating new interpolated sample at: 1.14874
# Creating new interpolated sample at: 1.15332
# Creating new interpolated sample at: 1.15789
# Creating new interpolated sample at: 1.16247
# Creating new interpolated sample at: 1.16705
# Creating new interpolated sample at: 1.17162
# Creating new interpolated sample at: 1.1762
# Creating new interpolated sample at: 1.18078
# Creating new interpolated sample at: 1.18535
# Creating new interpolated sample at: 1.18993
# Creating new interpolated sample at: 1.19451
# Creating new interpolated sample at: 1.19908
# Creating new interpolated sample at: 1.20366
# Creating new interpolated sample at: 1.20824
# Creating new interpolated sample at: 1.21281
# Creating new interpolated sample at: 1.21739
# Creating new interpolated sample at: 1.22197
# Creating new interpolated sample at: 1.22654
# Creating new interpolated sample at: 1.23112
# Creating new interpolated sample at: 1.2357
# Creating new interpolated sample at: 1.24027
# Creating new interpolated sample at: 1.24485
# Creating new interpolated sample at: 1.24943
# Creating new interpolated sample at: 1.254
# Creating new interpolated sample at: 1.25858
# Creating new interpolated sample at: 1.26316
# Creating new interpolated sample at: 1.26773
# Creating new interpolated sample at: 1.27231
# Creating new interpolated sample at: 1.27689
# Creating new interpolated sample at: 1.28146
# Creating new interpolated sample at: 1.28604
# Creating new interpolated sample at: 1.29062
# Creating new interpolated sample at: 1.29519
# Creating new interpolated sample at: 1.29977
# Creating new interpolated sample at: 1.30435
# Creating new interpolated sample at: 1.30892
# Creating new interpolated sample at: 1.3135
# Creating new interpolated sample at: 1.31808
# Creating new interpolated sample at: 1.32265
# Creating new interpolated sample at: 1.32723
# Creating new interpolated sample at: 1.33181
# Creating new interpolated sample at: 1.33638
# Creating new interpolated sample at: 1.34096
# Creating new interpolated sample at: 1.34554
# Creating new interpolated sample at: 1.35011
# Creating new interpolated sample at: 1.35469
# Creating new interpolated sample at: 1.35927
# Creating new interpolated sample at: 1.36384
# Creating new interpolated sample at: 1.36842
# Creating new interpolated sample at: 1.373
# Creating new interpolated sample at: 1.37757
# Creating new interpolated sample at: 1.38215
# Creating new interpolated sample at: 1.38673
# Creating new interpolated sample at: 1.3913
# Creating new interpolated sample at: 1.39588
# Creating new interpolated sample at: 1.40046
# Creating new interpolated sample at: 1.40503
# Creating new interpolated sample at: 1.40961
# Creating new interpolated sample at: 1.41419
# Creating new interpolated sample at: 1.41876
# Creating new interpolated sample at: 1.42334
# Creating new interpolated sample at: 1.42792
# Creating new interpolated sample at: 1.43249
# Creating new interpolated sample at: 1.43707
# Creating new interpolated sample at: 1.44165
# Creating new interpolated sample at: 1.44622
# Creating new interpolated sample at: 1.4508
# Creating new interpolated sample at: 1.45538
# Creating new interpolated sample at: 1.45995
# Creating new interpolated sample at: 1.46453
# Creating new interpolated sample at: 1.46911
# Creating new interpolated sample at: 1.47368
# Creating new interpolated sample at: 1.47826
# Creating new interpolated sample at: 1.48284
# Creating new interpolated sample at: 1.48741
# Creating new interpolated sample at: 1.49199
# Creating new interpolated sample at: 1.49657
# Creating new interpolated sample at: 1.50114
# Creating new interpolated sample at: 1.50572
# Creating new interpolated sample at: 1.5103
# Creating new interpolated sample at: 1.51487
# Creating new interpolated sample at: 1.51945
# Creating new interpolated sample at: 1.52403
# Creating new interpolated sample at: 1.5286
# Creating new interpolated sample at: 1.53318
# Creating new interpolated sample at: 1.53776
# Creating new interpolated sample at: 1.54233
# Creating new interpolated sample at: 1.54691
# Creating new interpolated sample at: 1.55149
# Creating new interpolated sample at: 1.55606
# Creating new interpolated sample at: 1.56064
# Creating new interpolated sample at: 1.56522
# Creating new interpolated sample at: 1.56979
# Creating new interpolated sample at: 1.57437
# Creating new interpolated sample at: 1.57895
# Creating new interpolated sample at: 1.58352
# Creating new interpolated sample at: 1.5881
# Creating new interpolated sample at: 1.59268
# Creating new interpolated sample at: 1.59725
# Creating new interpolated sample at: 1.60183
# Creating new interpolated sample at: 1.60641
# Creating new interpolated sample at: 1.61098
# Creating new interpolated sample at: 1.61556
# Creating new interpolated sample at: 1.62014
# Creating new interpolated sample at: 1.62471
# Creating new interpolated sample at: 1.62929
# Creating new interpolated sample at: 1.63387
# Creating new interpolated sample at: 1.63844
# Creating new interpolated sample at: 1.64302
# Creating new interpolated sample at: 1.6476
# Creating new interpolated sample at: 1.65217
# Creating new interpolated sample at: 1.65675
# Creating new interpolated sample at: 1.66133
# Creating new interpolated sample at: 1.6659
# Creating new interpolated sample at: 1.67048
# Creating new interpolated sample at: 1.67506
# Creating new interpolated sample at: 1.67963
# Creating new interpolated sample at: 1.68421
# Creating new interpolated sample at: 1.68879
# Creating new interpolated sample at: 1.69336
# Creating new interpolated sample at: 1.69794
# Creating new interpolated sample at: 1.70252
# Creating new interpolated sample at: 1.70709
# Creating new interpolated sample at: 1.71167
# Creating new interpolated sample at: 1.71625
# Creating new interpolated sample at: 1.72082
# Creating new interpolated sample at: 1.7254
# Creating new interpolated sample at: 1.72998
# Creating new interpolated sample at: 1.73455
# Creating new interpolated sample at: 1.73913
# Creating new interpolated sample at: 1.74371
# Creating new interpolated sample at: 1.74828
# Creating new interpolated sample at: 1.75286
# Creating new interpolated sample at: 1.75744
# Creating new interpolated sample at: 1.76201
# Creating new interpolated sample at: 1.76659
# Creating new interpolated sample at: 1.77117
# Creating new interpolated sample at: 1.77574
# Creating new interpolated sample at: 1.78032
# Creating new interpolated sample at: 1.7849
# Creating new interpolated sample at: 1.78947
# Creating new interpolated sample at: 1.79405
# Creating new interpolated sample at: 1.79863
# Creating new interpolated sample at: 1.8032
# Creating new interpolated sample at: 1.80778
# Creating new interpolated sample at: 1.81236
# Creating new interpolated sample at: 1.81693
# Creating new interpolated sample at: 1.82151
# Creating new interpolated sample at: 1.82609
# Creating new interpolated sample at: 1.83066
# Creating new interpolated sample at: 1.83524
# Creating new interpolated sample at: 1.83982
# Creating new interpolated sample at: 1.84439
# Creating new interpolated sample at: 1.84897
# Creating new interpolated sample at: 1.85355
# Creating new interpolated sample at: 1.85812
# Creating new interpolated sample at: 1.8627
# Creating new interpolated sample at: 1.86728
# Creating new interpolated sample at: 1.87185
# Creating new interpolated sample at: 1.87643
# Creating new interpolated sample at: 1.88101
# Creating new interpolated sample at: 1.88558
# Creating new interpolated sample at: 1.89016
# Creating new interpolated sample at: 1.89474
# Creating new interpolated sample at: 1.89931
# Creating new interpolated sample at: 1.90389
# Creating new interpolated sample at: 1.90847
# Creating new interpolated sample at: 1.91304
# Creating new interpolated sample at: 1.91762
# Creating new interpolated sample at: 1.9222
# Creating new interpolated sample at: 1.92677
# Creating new interpolated sample at: 1.93135
# Creating new interpolated sample at: 1.93593
# Creating new interpolated sample at: 1.9405
# Creating new interpolated sample at: 1.94508
# Creating new interpolated sample at: 1.94966
# Creating new interpolated sample at: 1.95423
# Creating new interpolated sample at: 1.95881
# Creating new interpolated sample at: 1.96339
# Creating new interpolated sample at: 1.96796
# Creating new interpolated sample at: 1.97254
# Creating new interpolated sample at: 1.97712
# Creating new interpolated sample at: 1.98169
# Creating new interpolated sample at: 1.98627
# Creating new interpolated sample at: 1.99085
# Creating new interpolated sample at: 1.99542
# Creating new interpolated sample at: 2
# Number of interpolated snapshots is: 438
# Using 10 basis vectors out of 437.
# Number of snapshots is: 438
# Setting desired dt to 0.00457666 to ensure a constant dt given the final sampled time.
# Creating new interpolated sample at: 0
# Creating new interpolated sample at: 0.00457666
# Creating new interpolated sample at: 0.00915332
# Creating new interpolated sample at: 0.01373
# Creating new interpolated sample at: 0.0183066
# Creating new interpolated sample at: 0.0228833
# Creating new interpolated sample at: 0.02746
# Creating new interpolated sample at: 0.0320366
# Creating new interpolated sample at: 0.0366133
# Creating new interpolated sample at: 0.0411899
# Creating new interpolated sample at: 0.0457666
# Creating new interpolated sample at: 0.0503432
# Creating new interpolated sample at: 0.0549199
# Creating new interpolated sample at: 0.0594966
# Creating new interpolated sample at: 0.0640732
# Creating new interpolated sample at: 0.0686499
# Creating new interpolated sample at: 0.0732265
# Creating new interpolated sample at: 0.0778032
# Creating new interpolated sample at: 0.0823799
# Creating new interpolated sample at: 0.0869565
# Creating new interpolated sample at: 0.0915332
# Creating new interpolated sample at: 0.0961098
# Creating new interpolated sample at: 0.100686
# Creating new interpolated sample at: 0.105263
# Creating new interpolated sample at: 0.10984
# Creating new interpolated sample at: 0.114416
# Creating new interpolated sample at: 0.118993
# Creating new interpolated sample at: 0.12357
# Creating new interpolated sample at: 0.128146
# Creating new interpolated sample at: 0.132723
# Creating new interpolated sample at: 0.1373
# Creating new interpolated sample at: 0.141876
# Creating new interpolated sample at: 0.146453
# Creating new interpolated sample at: 0.15103
# Creating new interpolated sample at: 0.155606
# Creating new interpolated sample at: 0.160183
# Creating new interpolated sample at: 0.16476
# Creating new interpolated sample at: 0.169336
# Creating new interpolated sample at: 0.173913
# Creating new interpolated sample at: 0.17849
# Creating new interpolated sample at: 0.183066
# Creating new interpolated sample at: 0.187643
# Creating new interpolated sample at: 0.19222
# Creating new interpolated sample at: 0.196796
# Creating new interpolated sample at: 0.201373
# Creating new interpolated sample at: 0.20595
# Creating new interpolated sample at: 0.210526
# Creating new interpolated sample at: 0.215103
# Creating new interpolated sample at: 0.21968
# Creating new interpolated sample at: 0.224256
# Creating new interpolated sample at: 0.228833
# Creating new interpolated sample at: 0.23341
# Creating new interpolated sample at: 0.237986
# Creating new interpolated sample at: 0.242563
# Creating new interpolated sample at: 0.24714
# Creating new interpolated sample at: 0.251716
# Creating new interpolated sample at: 0.256293
# Creating new interpolated sample at: 0.26087
# Creating new interpolated sample at: 0.265446
# Creating new interpolated sample at: 0.270023
# Creating new interpolated sample at: 0.2746
# Creating new interpolated sample at: 0.279176
# Creating new interpolated sample at: 0.283753
# Creating new interpolated sample at: 0.28833
# Creating new interpolated sample at: 0.292906
# Creating new interpolated sample at: 0.297483
# Creating new interpolated sample at: 0.302059
# Creating new interpolated sample at: 0.306636
# Creating new interpolated sample at: 0.311213
# Creating new interpolated sample at: 0.315789
# Creating new interpolated sample at: 0.320366
# Creating new interpolated sample at: 0.324943
# Creating new interpolated sample at: 0.329519
# Creating new interpolated sample at: 0.334096
# Creating new interpolated sample at: 0.338673
# Creating new interpolated sample at: 0.343249
# Creating new interpolated sample at: 0.347826
# Creating new interpolated sample at: 0.352403
# Creating new interpolated sample at: 0.356979
# Creating new interpolated sample at: 0.361556
# Creating new interpolated sample at: 0.366133
# Creating new interpolated sample at: 0.370709
# Creating new interpolated sample at: 0.375286
# Creating new interpolated sample at: 0.379863
# Creating new interpolated sample at: 0.384439
# Creating new interpolated sample at: 0.389016
# Creating new interpolated sample at: 0.393593
# Creating new interpolated sample at: 0.398169
# Creating new interpolated sample at: 0.402746
# Creating new interpolated sample at: 0.407323
# Creating new interpolated sample at: 0.411899
# Creating new interpolated sample at: 0.416476
# Creating new interpolated sample at: 0.421053
# Creating new interpolated sample at: 0.425629
# Creating new interpolated sample at: 0.430206
# Creating new interpolated sample at: 0.434783
# Creating new interpolated sample at: 0.439359
# Creating new interpolated sample at: 0.443936
# Creating new interpolated sample at: 0.448513
# Creating new interpolated sample at: 0.453089
# Creating new interpolated sample at: 0.457666
# Creating new interpolated sample at: 0.462243
# Creating new interpolated sample at: 0.466819
# Creating new interpolated sample at: 0.471396
# Creating new interpolated sample at: 0.475973
# Creating new interpolated sample at: 0.480549
# Creating new interpolated sample at: 0.485126
# Creating new interpolated sample at: 0.489703
# Creating new interpolated sample at: 0.494279
# Creating new interpolated sample at: 0.498856
# Creating new interpolated sample at: 0.503432
# Creating new interpolated sample at: 0.508009
# Creating new interpolated sample at: 0.512586
# Creating new interpolated sample at: 0.517162
# Creating new interpolated sample at: 0.521739
# Creating new interpolated sample at: 0.526316
# Creating new interpolated sample at: 0.530892
# Creating new interpolated sample at: 0.535469
# Creating new interpolated sample at: 0.540046
# Creating new interpolated sample at: 0.544622
# Creating new interpolated sample at: 0.549199
# Creating new interpolated sample at: 0.553776
# Creating new interpolated sample at: 0.558352
# Creating new interpolated sample at: 0.562929
# Creating new interpolated sample at: 0.567506
# Creating new interpolated sample at: 0.572082
# Creating new interpolated sample at: 0.576659
# Creating new interpolated sample at: 0.581236
# Creating new interpolated sample at: 0.585812
# Creating new interpolated sample at: 0.590389
# Creating new interpolated sample at: 0.594966
# Creating new interpolated sample at: 0.599542
# Creating new interpolated sample at: 0.604119
# Creating new interpolated sample at: 0.608696
# Creating new interpolated sample at: 0.613272
# Creating new interpolated sample at: 0.617849
# Creating new interpolated sample at: 0.622426
# Creating new interpolated sample at: 0.627002
# Creating new interpolated sample at: 0.631579
# Creating new interpolated sample at: 0.636156
# Creating new interpolated sample at: 0.640732
# Creating new interpolated sample at: 0.645309
# Creating new interpolated sample at: 0.649886
# Creating new interpolated sample at: 0.654462
# Creating new interpolated sample at: 0.659039
# Creating new interpolated sample at: 0.663616
# Creating new interpolated sample at: 0.668192
# Creating new interpolated sample at: 0.672769
# Creating new interpolated sample at: 0.677346
# Creating new interpolated sample at: 0.681922
# Creating new interpolated sample at: 0.686499
# Creating new interpolated sample at: 0.691076
# Creating new interpolated sample at: 0.695652
# Creating new interpolated sample at: 0.700229
# Creating new interpolated sample at: 0.704805
# Creating new interpolated sample at: 0.709382
# Creating new interpolated sample at: 0.713959
# Creating new interpolated sample at: 0.718535
# Creating new interpolated sample at: 0.723112
# Creating new interpolated sample at: 0.727689
# Creating new interpolated sample at: 0.732265
# Creating new interpolated sample at: 0.736842
# Creating new interpolated sample at: 0.741419
# Creating new interpolated sample at: 0.745995
# Creating new interpolated sample at: 0.750572
# Creating new interpolated sample at: 0.755149
# Creating new interpolated sample at: 0.759725
# Creating new interpolated sample at: 0.764302
# Creating new interpolated sample at: 0.768879
# Creating new interpolated sample at: 0.773455
# Creating new interpolated sample at: 0.778032
# Creating new interpolated sample at: 0.782609
# Creating new interpolated sample at: 0.787185
# Creating new interpolated sample at: 0.791762
# Creating new interpolated sample at: 0.796339
# Creating new interpolated sample at: 0.800915
# Creating new interpolated sample at: 0.805492
# Creating new interpolated sample at: 0.810069
# Creating new interpolated sample at: 0.814645
# Creating new interpolated sample at: 0.819222
# Creating new interpolated sample at: 0.823799
# Creating new interpolated sample at: 0.828375
# Creating new interpolated sample at: 0.832952
# Creating new interpolated sample at: 0.837529
# Creating new interpolated sample at: 0.842105
# Creating new interpolated sample at: 0.846682
# Creating new interpolated sample at: 0.851259
# Creating new interpolated sample at: 0.855835
# Creating new interpolated sample at: 0.860412
# Creating new interpolated sample at: 0.864989
# Creating new interpolated sample at: 0.869565
# Creating new interpolated sample at: 0.874142
# Creating new interpolated sample at: 0.878719
# Creating new interpolated sample at: 0.883295
# Creating new interpolated sample at: 0.887872
# Creating new interpolated sample at: 0.892449
# Creating new interpolated sample at: 0.897025
# Creating new interpolated sample at: 0.901602
# Creating new interpolated sample at: 0.906178
# Creating new interpolated sample at: 0.910755
# Creating new interpolated sample at: 0.915332
# Creating new interpolated sample at: 0.919908
# Creating new interpolated sample at: 0.924485
# Creating new interpolated sample at: 0.929062
# Creating new interpolated sample at: 0.933638
# Creating new interpolated sample at: 0.938215
# Creating new interpolated sample at: 0.942792
# Creating new interpolated sample at: 0.947368
# Creating new interpolated sample at: 0.951945
# Creating new interpolated sample at: 0.956522
# Creating new interpolated sample at: 0.961098
# Creating new interpolated sample at: 0.965675
# Creating new interpolated sample at: 0.970252
# Creating new interpolated sample at: 0.974828
# Creating new interpolated sample at: 0.979405
# Creating new interpolated sample at: 0.983982
# Creating new interpolated sample at: 0.988558
# Creating new interpolated sample at: 0.993135
# Creating new interpolated sample at: 0.997712
# Creating new interpolated sample at: 1.00229
# Creating new interpolated sample at: 1.00686
# Creating new interpolated sample at: 1.01144
# Creating new interpolated sample at: 1.01602
# Creating new interpolated sample at: 1.02059
# Creating new interpolated sample at: 1.02517
# Creating new interpolated sample at: 1.02975
# Creating new interpolated sample at: 1.03432
# Creating new interpolated sample at: 1.0389
# Creating new interpolated sample at: 1.04348
# Creating new interpolated sample at: 1.04805
# Creating new interpolated sample at: 1.05263
# Creating new interpolated sample at: 1.05721
# Creating new interpolated sample at: 1.06178
# Creating new interpolated sample at: 1.06636
# Creating new interpolated sample at: 1.07094
# Creating new interpolated sample at: 1.07551
# Creating new interpolated sample at: 1.08009
# Creating new interpolated sample at: 1.08467
# Creating new interpolated sample at: 1.08924
# Creating new interpolated sample at: 1.09382
# Creating new interpolated sample at: 1.0984
# Creating new interpolated sample at: 1.10297
# Creating new interpolated sample at: 1.10755
# Creating new interpolated sample at: 1.11213
# Creating new interpolated sample at: 1.1167
# Creating new interpolated sample at: 1.12128
# Creating new interpolated sample at: 1.12586
# Creating new interpolated sample at: 1.13043
# Creating new interpolated sample at: 1.13501
# Creating new interpolated sample at: 1.13959
# Creating new interpolated sample at: 1.14416
# Creating new interpolated sample at: 1.14874
# Creating new interpolated sample at: 1.15332
# Creating new interpolated sample at: 1.15789
# Creating new interpolated sample at: 1.16247
# Creating new interpolated sample at: 1.16705
# Creating new interpolated sample at: 1.17162
# Creating new interpolated sample at: 1.1762
# Creating new interpolated sample at: 1.18078
# Creating new interpolated sample at: 1.18535
# Creating new interpolated sample at: 1.18993
# Creating new interpolated sample at: 1.19451
# Creating new interpolated sample at: 1.19908
# Creating new interpolated sample at: 1.20366
# Creating new interpolated sample at: 1.20824
# Creating new interpolated sample at: 1.21281
# Creating new interpolated sample at: 1.21739
# Creating new interpolated sample at: 1.22197
# Creating new interpolated sample at: 1.22654
# Creating new interpolated sample at: 1.23112
# Creating new interpolated sample at: 1.2357
# Creating new interpolated sample at: 1.24027
# Creating new interpolated sample at: 1.24485
# Creating new interpolated sample at: 1.24943
# Creating new interpolated sample at: 1.254
# Creating new interpolated sample at: 1.25858
# Creating new interpolated sample at: 1.26316
# Creating new interpolated sample at: 1.26773
# Creating new interpolated sample at: 1.27231
# Creating new interpolated sample at: 1.27689
# Creating new interpolated sample at: 1.28146
# Creating new interpolated sample at: 1.28604
# Creating new interpolated sample at: 1.29062
# Creating new interpolated sample at: 1.29519
# Creating new interpolated sample at: 1.29977
# Creating new interpolated sample at: 1.30435
# Creating new interpolated sample at: 1.30892
# Creating new interpolated sample at: 1.3135
# Creating new interpolated sample at: 1.31808
# Creating new interpolated sample at: 1.32265
# Creating new interpolated sample at: 1.32723
# Creating new interpolated sample at: 1.33181
# Creating new interpolated sample at: 1.33638
# Creating new interpolated sample at: 1.34096
# Creating new interpolated sample at: 1.34554
# Creating new interpolated sample at: 1.35011
# Creating new interpolated sample at: 1.35469
# Creating new interpolated sample at: 1.35927
# Creating new interpolated sample at: 1.36384
# Creating new interpolated sample at: 1.36842
# Creating new interpolated sample at: 1.373
# Creating new interpolated sample at: 1.37757
# Creating new interpolated sample at: 1.38215
# Creating new interpolated sample at: 1.38673
# Creating new interpolated sample at: 1.3913
# Creating new interpolated sample at: 1.39588
# Creating new interpolated sample at: 1.40046
# Creating new interpolated sample at: 1.40503
# Creating new interpolated sample at: 1.40961
# Creating new interpolated sample at: 1.41419
# Creating new interpolated sample at: 1.41876
# Creating new interpolated sample at: 1.42334
# Creating new interpolated sample at: 1.42792
# Creating new interpolated sample at: 1.43249
# Creating new interpolated sample at: 1.43707
# Creating new interpolated sample at: 1.44165
# Creating new interpolated sample at: 1.44622
# Creating new interpolated sample at: 1.4508
# Creating new interpolated sample at: 1.45538
# Creating new interpolated sample at: 1.45995
# Creating new interpolated sample at: 1.46453
# Creating new interpolated sample at: 1.46911
# Creating new interpolated sample at: 1.47368
# Creating new interpolated sample at: 1.47826
# Creating new interpolated sample at: 1.48284
# Creating new interpolated sample at: 1.48741
# Creating new interpolated sample at: 1.49199
# Creating new interpolated sample at: 1.49657
# Creating new interpolated sample at: 1.50114
# Creating new interpolated sample at: 1.50572
# Creating new interpolated sample at: 1.5103
# Creating new interpolated sample at: 1.51487
# Creating new interpolated sample at: 1.51945
# Creating new interpolated sample at: 1.52403
# Creating new interpolated sample at: 1.5286
# Creating new interpolated sample at: 1.53318
# Creating new interpolated sample at: 1.53776
# Creating new interpolated sample at: 1.54233
# Creating new interpolated sample at: 1.54691
# Creating new interpolated sample at: 1.55149
# Creating new interpolated sample at: 1.55606
# Creating new interpolated sample at: 1.56064
# Creating new interpolated sample at: 1.56522
# Creating new interpolated sample at: 1.56979
# Creating new interpolated sample at: 1.57437
# Creating new interpolated sample at: 1.57895
# Creating new interpolated sample at: 1.58352
# Creating new interpolated sample at: 1.5881
# Creating new interpolated sample at: 1.59268
# Creating new interpolated sample at: 1.59725
# Creating new interpolated sample at: 1.60183
# Creating new interpolated sample at: 1.60641
# Creating new interpolated sample at: 1.61098
# Creating new interpolated sample at: 1.61556
# Creating new interpolated sample at: 1.62014
# Creating new interpolated sample at: 1.62471
# Creating new interpolated sample at: 1.62929
# Creating new interpolated sample at: 1.63387
# Creating new interpolated sample at: 1.63844
# Creating new interpolated sample at: 1.64302
# Creating new interpolated sample at: 1.6476
# Creating new interpolated sample at: 1.65217
# Creating new interpolated sample at: 1.65675
# Creating new interpolated sample at: 1.66133
# Creating new interpolated sample at: 1.6659
# Creating new interpolated sample at: 1.67048
# Creating new interpolated sample at: 1.67506
# Creating new interpolated sample at: 1.67963
# Creating new interpolated sample at: 1.68421
# Creating new interpolated sample at: 1.68879
# Creating new interpolated sample at: 1.69336
# Creating new interpolated sample at: 1.69794
# Creating new interpolated sample at: 1.70252
# Creating new interpolated sample at: 1.70709
# Creating new interpolated sample at: 1.71167
# Creating new interpolated sample at: 1.71625
# Creating new interpolated sample at: 1.72082
# Creating new interpolated sample at: 1.7254
# Creating new interpolated sample at: 1.72998
# Creating new interpolated sample at: 1.73455
# Creating new interpolated sample at: 1.73913
# Creating new interpolated sample at: 1.74371
# Creating new interpolated sample at: 1.74828
# Creating new interpolated sample at: 1.75286
# Creating new interpolated sample at: 1.75744
# Creating new interpolated sample at: 1.76201
# Creating new interpolated sample at: 1.76659
# Creating new interpolated sample at: 1.77117
# Creating new interpolated sample at: 1.77574
# Creating new interpolated sample at: 1.78032
# Creating new interpolated sample at: 1.7849
# Creating new interpolated sample at: 1.78947
# Creating new interpolated sample at: 1.79405
# Creating new interpolated sample at: 1.79863
# Creating new interpolated sample at: 1.8032
# Creating new interpolated sample at: 1.80778
# Creating new interpolated sample at: 1.81236
# Creating new interpolated sample at: 1.81693
# Creating new interpolated sample at: 1.82151
# Creating new interpolated sample at: 1.82609
# Creating new interpolated sample at: 1.83066
# Creating new interpolated sample at: 1.83524
# Creating new interpolated sample at: 1.83982
# Creating new interpolated sample at: 1.84439
# Creating new interpolated sample at: 1.84897
# Creating new interpolated sample at: 1.85355
# Creating new interpolated sample at: 1.85812
# Creating new interpolated sample at: 1.8627
# Creating new interpolated sample at: 1.86728
# Creating new interpolated sample at: 1.87185
# Creating new interpolated sample at: 1.87643
# Creating new interpolated sample at: 1.88101
# Creating new interpolated sample at: 1.88558
# Creating new interpolated sample at: 1.89016
# Creating new interpolated sample at: 1.89474
# Creating new interpolated sample at: 1.89931
# Creating new interpolated sample at: 1.90389
# Creating new interpolated sample at: 1.90847
# Creating new interpolated sample at: 1.91304
# Creating new interpolated sample at: 1.91762
# Creating new interpolated sample at: 1.9222
# Creating new interpolated sample at: 1.92677
# Creating new interpolated sample at: 1.93135
# Creating new interpolated sample at: 1.93593
# Creating new interpolated sample at: 1.9405
# Creating new interpolated sample at: 1.94508
# Creating new interpolated sample at: 1.94966
# Creating new interpolated sample at: 1.95423
# Creating new interpolated sample at: 1.95881
# Creating new interpolated sample at: 1.96339
# Creating new interpolated sample at: 1.96796
# Creating new interpolated sample at: 1.97254
# Creating new interpolated sample at: 1.97712
# Creating new interpolated sample at: 1.98169
# Creating new interpolated sample at: 1.98627
# Creating new interpolated sample at: 1.99085
# Creating new interpolated sample at: 1.99542
# Creating new interpolated sample at: 2
# Number of interpolated snapshots is: 438
# Using 13 basis vectors out of 437.
# Number of snapshots is: 438
# Setting desired dt to 0.00457666 to ensure a constant dt given the final sampled time.
# Creating new interpolated sample at: 0
# Creating new interpolated sample at: 0.00457666
# Creating new interpolated sample at: 0.00915332
# Creating new interpolated sample at: 0.01373
# Creating new interpolated sample at: 0.0183066
# Creating new interpolated sample at: 0.0228833
# Creating new interpolated sample at: 0.02746
# Creating new interpolated sample at: 0.0320366
# Creating new interpolated sample at: 0.0366133
# Creating new interpolated sample at: 0.0411899
# Creating new interpolated sample at: 0.0457666
# Creating new interpolated sample at: 0.0503432
# Creating new interpolated sample at: 0.0549199
# Creating new interpolated sample at: 0.0594966
# Creating new interpolated sample at: 0.0640732
# Creating new interpolated sample at: 0.0686499
# Creating new interpolated sample at: 0.0732265
# Creating new interpolated sample at: 0.0778032
# Creating new interpolated sample at: 0.0823799
# Creating new interpolated sample at: 0.0869565
# Creating new interpolated sample at: 0.0915332
# Creating new interpolated sample at: 0.0961098
# Creating new interpolated sample at: 0.100686
# Creating new interpolated sample at: 0.105263
# Creating new interpolated sample at: 0.10984
# Creating new interpolated sample at: 0.114416
# Creating new interpolated sample at: 0.118993
# Creating new interpolated sample at: 0.12357
# Creating new interpolated sample at: 0.128146
# Creating new interpolated sample at: 0.132723
# Creating new interpolated sample at: 0.1373
# Creating new interpolated sample at: 0.141876
# Creating new interpolated sample at: 0.146453
# Creating new interpolated sample at: 0.15103
# Creating new interpolated sample at: 0.155606
# Creating new interpolated sample at: 0.160183
# Creating new interpolated sample at: 0.16476
# Creating new interpolated sample at: 0.169336
# Creating new interpolated sample at: 0.173913
# Creating new interpolated sample at: 0.17849
# Creating new interpolated sample at: 0.183066
# Creating new interpolated sample at: 0.187643
# Creating new interpolated sample at: 0.19222
# Creating new interpolated sample at: 0.196796
# Creating new interpolated sample at: 0.201373
# Creating new interpolated sample at: 0.20595
# Creating new interpolated sample at: 0.210526
# Creating new interpolated sample at: 0.215103
# Creating new interpolated sample at: 0.21968
# Creating new interpolated sample at: 0.224256
# Creating new interpolated sample at: 0.228833
# Creating new interpolated sample at: 0.23341
# Creating new interpolated sample at: 0.237986
# Creating new interpolated sample at: 0.242563
# Creating new interpolated sample at: 0.24714
# Creating new interpolated sample at: 0.251716
# Creating new interpolated sample at: 0.256293
# Creating new interpolated sample at: 0.26087
# Creating new interpolated sample at: 0.265446
# Creating new interpolated sample at: 0.270023
# Creating new interpolated sample at: 0.2746
# Creating new interpolated sample at: 0.279176
# Creating new interpolated sample at: 0.283753
# Creating new interpolated sample at: 0.28833
# Creating new interpolated sample at: 0.292906
# Creating new interpolated sample at: 0.297483
# Creating new interpolated sample at: 0.302059
# Creating new interpolated sample at: 0.306636
# Creating new interpolated sample at: 0.311213
# Creating new interpolated sample at: 0.315789
# Creating new interpolated sample at: 0.320366
# Creating new interpolated sample at: 0.324943
# Creating new interpolated sample at: 0.329519
# Creating new interpolated sample at: 0.334096
# Creating new interpolated sample at: 0.338673
# Creating new interpolated sample at: 0.343249
# Creating new interpolated sample at: 0.347826
# Creating new interpolated sample at: 0.352403
# Creating new interpolated sample at: 0.356979
# Creating new interpolated sample at: 0.361556
# Creating new interpolated sample at: 0.366133
# Creating new interpolated sample at: 0.370709
# Creating new interpolated sample at: 0.375286
# Creating new interpolated sample at: 0.379863
# Creating new interpolated sample at: 0.384439
# Creating new interpolated sample at: 0.389016
# Creating new interpolated sample at: 0.393593
# Creating new interpolated sample at: 0.398169
# Creating new interpolated sample at: 0.402746
# Creating new interpolated sample at: 0.407323
# Creating new interpolated sample at: 0.411899
# Creating new interpolated sample at: 0.416476
# Creating new interpolated sample at: 0.421053
# Creating new interpolated sample at: 0.425629
# Creating new interpolated sample at: 0.430206
# Creating new interpolated sample at: 0.434783
# Creating new interpolated sample at: 0.439359
# Creating new interpolated sample at: 0.443936
# Creating new interpolated sample at: 0.448513
# Creating new interpolated sample at: 0.453089
# Creating new interpolated sample at: 0.457666
# Creating new interpolated sample at: 0.462243
# Creating new interpolated sample at: 0.466819
# Creating new interpolated sample at: 0.471396
# Creating new interpolated sample at: 0.475973
# Creating new interpolated sample at: 0.480549
# Creating new interpolated sample at: 0.485126
# Creating new interpolated sample at: 0.489703
# Creating new interpolated sample at: 0.494279
# Creating new interpolated sample at: 0.498856
# Creating new interpolated sample at: 0.503432
# Creating new interpolated sample at: 0.508009
# Creating new interpolated sample at: 0.512586
# Creating new interpolated sample at: 0.517162
# Creating new interpolated sample at: 0.521739
# Creating new interpolated sample at: 0.526316
# Creating new interpolated sample at: 0.530892
# Creating new interpolated sample at: 0.535469
# Creating new interpolated sample at: 0.540046
# Creating new interpolated sample at: 0.544622
# Creating new interpolated sample at: 0.549199
# Creating new interpolated sample at: 0.553776
# Creating new interpolated sample at: 0.558352
# Creating new interpolated sample at: 0.562929
# Creating new interpolated sample at: 0.567506
# Creating new interpolated sample at: 0.572082
# Creating new interpolated sample at: 0.576659
# Creating new interpolated sample at: 0.581236
# Creating new interpolated sample at: 0.585812
# Creating new interpolated sample at: 0.590389
# Creating new interpolated sample at: 0.594966
# Creating new interpolated sample at: 0.599542
# Creating new interpolated sample at: 0.604119
# Creating new interpolated sample at: 0.608696
# Creating new interpolated sample at: 0.613272
# Creating new interpolated sample at: 0.617849
# Creating new interpolated sample at: 0.622426
# Creating new interpolated sample at: 0.627002
# Creating new interpolated sample at: 0.631579
# Creating new interpolated sample at: 0.636156
# Creating new interpolated sample at: 0.640732
# Creating new interpolated sample at: 0.645309
# Creating new interpolated sample at: 0.649886
# Creating new interpolated sample at: 0.654462
# Creating new interpolated sample at: 0.659039
# Creating new interpolated sample at: 0.663616
# Creating new interpolated sample at: 0.668192
# Creating new interpolated sample at: 0.672769
# Creating new interpolated sample at: 0.677346
# Creating new interpolated sample at: 0.681922
# Creating new interpolated sample at: 0.686499
# Creating new interpolated sample at: 0.691076
# Creating new interpolated sample at: 0.695652
# Creating new interpolated sample at: 0.700229
# Creating new interpolated sample at: 0.704805
# Creating new interpolated sample at: 0.709382
# Creating new interpolated sample at: 0.713959
# Creating new interpolated sample at: 0.718535
# Creating new interpolated sample at: 0.723112
# Creating new interpolated sample at: 0.727689
# Creating new interpolated sample at: 0.732265
# Creating new interpolated sample at: 0.736842
# Creating new interpolated sample at: 0.741419
# Creating new interpolated sample at: 0.745995
# Creating new interpolated sample at: 0.750572
# Creating new interpolated sample at: 0.755149
# ...
# Creating new interpolated sample at: 0.398169
# Creating new interpolated sample at: 0.402746
# Creating new interpolated sample at: 0.407323
# Creating new interpolated sample at: 0.411899
# Creating new interpolated sample at: 0.416476
# Creating new interpolated sample at: 0.421053
# Creating new interpolated sample at: 0.425629
# Creating new interpolated sample at: 0.430206
# Creating new interpolated sample at: 0.434783
# Creating new interpolated sample at: 0.439359
# Creating new interpolated sample at: 0.443936
# Creating new interpolated sample at: 0.448513
# Creating new interpolated sample at: 0.453089
# Creating new interpolated sample at: 0.457666
# Creating new interpolated sample at: 0.462243
# Creating new interpolated sample at: 0.466819
# Creating new interpolated sample at: 0.471396
# Creating new interpolated sample at: 0.475973
# Creating new interpolated sample at: 0.480549
# Creating new interpolated sample at: 0.485126
# Creating new interpolated sample at: 0.489703
# Creating new interpolated sample at: 0.494279
# Creating new interpolated sample at: 0.498856
# Creating new interpolated sample at: 0.503432
# Creating new interpolated sample at: 0.508009
# Creating new interpolated sample at: 0.512586
# Creating new interpolated sample at: 0.517162
# Creating new interpolated sample at: 0.521739
# Creating new interpolated sample at: 0.526316
# Creating new interpolated sample at: 0.530892
# Creating new interpolated sample at: 0.535469
# Creating new interpolated sample at: 0.540046
# Creating new interpolated sample at: 0.544622
# Creating new interpolated sample at: 0.549199
# Creating new interpolated sample at: 0.553776
# Creating new interpolated sample at: 0.558352
# Creating new interpolated sample at: 0.562929
# Creating new interpolated sample at: 0.567506
# Creating new interpolated sample at: 0.572082
# Creating new interpolated sample at: 0.576659
# Creating new interpolated sample at: 0.581236
# Creating new interpolated sample at: 0.585812
# Creating new interpolated sample at: 0.590389
# Creating new interpolated sample at: 0.594966
# Creating new interpolated sample at: 0.599542
# Creating new interpolated sample at: 0.604119
# Creating new interpolated sample at: 0.608696
# Creating new interpolated sample at: 0.613272
# Creating new interpolated sample at: 0.617849
# Creating new interpolated sample at: 0.622426
# Creating new interpolated sample at: 0.627002
# Creating new interpolated sample at: 0.631579
# Creating new interpolated sample at: 0.636156
# Creating new interpolated sample at: 0.640732
# Creating new interpolated sample at: 0.645309
# Creating new interpolated sample at: 0.649886
# Creating new interpolated sample at: 0.654462
# Creating new interpolated sample at: 0.659039
# Creating new interpolated sample at: 0.663616
# Creating new interpolated sample at: 0.668192
# Creating new interpolated sample at: 0.672769
# Creating new interpolated sample at: 0.677346
# Creating new interpolated sample at: 0.681922
# Creating new interpolated sample at: 0.686499
# Creating new interpolated sample at: 0.691076
# Creating new interpolated sample at: 0.695652
# Creating new interpolated sample at: 0.700229
# Creating new interpolated sample at: 0.704805
# Creating new interpolated sample at: 0.709382
# Creating new interpolated sample at: 0.713959
# Creating new interpolated sample at: 0.718535
# Creating new interpolated sample at: 0.723112
# Creating new interpolated sample at: 0.727689
# Creating new interpolated sample at: 0.732265
# Creating new interpolated sample at: 0.736842
# Creating new interpolated sample at: 0.741419
# Creating new interpolated sample at: 0.745995
# Creating new interpolated sample at: 0.750572
# Creating new interpolated sample at: 0.755149
# Creating new interpolated sample at: 0.759725
# Creating new interpolated sample at: 0.764302
# Creating new interpolated sample at: 0.768879
# Creating new interpolated sample at: 0.773455
# Creating new interpolated sample at: 0.778032
# Creating new interpolated sample at: 0.782609
# Creating new interpolated sample at: 0.787185
# Creating new interpolated sample at: 0.791762
# Creating new interpolated sample at: 0.796339
# Creating new interpolated sample at: 0.800915
# Creating new interpolated sample at: 0.805492
# Creating new interpolated sample at: 0.810069
# Creating new interpolated sample at: 0.814645
# Creating new interpolated sample at: 0.819222
# Creating new interpolated sample at: 0.823799
# Creating new interpolated sample at: 0.828375
# Creating new interpolated sample at: 0.832952
# Creating new interpolated sample at: 0.837529
# Creating new interpolated sample at: 0.842105
# Creating new interpolated sample at: 0.846682
# Creating new interpolated sample at: 0.851259
# Creating new interpolated sample at: 0.855835
# Creating new interpolated sample at: 0.860412
# Creating new interpolated sample at: 0.864989
# Creating new interpolated sample at: 0.869565
# Creating new interpolated sample at: 0.874142
# Creating new interpolated sample at: 0.878719
# Creating new interpolated sample at: 0.883295
# Creating new interpolated sample at: 0.887872
# Creating new interpolated sample at: 0.892449
# Creating new interpolated sample at: 0.897025
# Creating new interpolated sample at: 0.901602
# Creating new interpolated sample at: 0.906178
# Creating new interpolated sample at: 0.910755
# Creating new interpolated sample at: 0.915332
# Creating new interpolated sample at: 0.919908
# Creating new interpolated sample at: 0.924485
# Creating new interpolated sample at: 0.929062
# Creating new interpolated sample at: 0.933638
# Creating new interpolated sample at: 0.938215
# Creating new interpolated sample at: 0.942792
# Creating new interpolated sample at: 0.947368
# Creating new interpolated sample at: 0.951945
# Creating new interpolated sample at: 0.956522
# Creating new interpolated sample at: 0.961098
# Creating new interpolated sample at: 0.965675
# Creating new interpolated sample at: 0.970252
# Creating new interpolated sample at: 0.974828
# Creating new interpolated sample at: 0.979405
# Creating new interpolated sample at: 0.983982
# Creating new interpolated sample at: 0.988558
# Creating new interpolated sample at: 0.993135
# Creating new interpolated sample at: 0.997712
# Creating new interpolated sample at: 1.00229
# Creating new interpolated sample at: 1.00686
# Creating new interpolated sample at: 1.01144
# Creating new interpolated sample at: 1.01602
# Creating new interpolated sample at: 1.02059
# Creating new interpolated sample at: 1.02517
# Creating new interpolated sample at: 1.02975
# Creating new interpolated sample at: 1.03432
# Creating new interpolated sample at: 1.0389
# Creating new interpolated sample at: 1.04348
# Creating new interpolated sample at: 1.04805
# Creating new interpolated sample at: 1.05263
# Creating new interpolated sample at: 1.05721
# Creating new interpolated sample at: 1.06178
# Creating new interpolated sample at: 1.06636
# Creating new interpolated sample at: 1.07094
# Creating new interpolated sample at: 1.07551
# Creating new interpolated sample at: 1.08009
# Creating new interpolated sample at: 1.08467
# Creating new interpolated sample at: 1.08924
# Creating new interpolated sample at: 1.09382
# Creating new interpolated sample at: 1.0984
# Creating new interpolated sample at: 1.10297
# Creating new interpolated sample at: 1.10755
# Creating new interpolated sample at: 1.11213
# Creating new interpolated sample at: 1.1167
# Creating new interpolated sample at: 1.12128
# Creating new interpolated sample at: 1.12586
# Creating new interpolated sample at: 1.13043
# Creating new interpolated sample at: 1.13501
# Creating new interpolated sample at: 1.13959
# Creating new interpolated sample at: 1.14416
# Creating new interpolated sample at: 1.14874
# Creating new interpolated sample at: 1.15332
# Creating new interpolated sample at: 1.15789
# Creating new interpolated sample at: 1.16247
# Creating new interpolated sample at: 1.16705
# Creating new interpolated sample at: 1.17162
# Creating new interpolated sample at: 1.1762
# Creating new interpolated sample at: 1.18078
# Creating new interpolated sample at: 1.18535
# Creating new interpolated sample at: 1.18993
# Creating new interpolated sample at: 1.19451
# Creating new interpolated sample at: 1.19908
# Creating new interpolated sample at: 1.20366
# Creating new interpolated sample at: 1.20824
# Creating new interpolated sample at: 1.21281
# Creating new interpolated sample at: 1.21739
# Creating new interpolated sample at: 1.22197
# Creating new interpolated sample at: 1.22654
# Creating new interpolated sample at: 1.23112
# Creating new interpolated sample at: 1.2357
# Creating new interpolated sample at: 1.24027
# Creating new interpolated sample at: 1.24485
# Creating new interpolated sample at: 1.24943
# Creating new interpolated sample at: 1.254
# Creating new interpolated sample at: 1.25858
# Creating new interpolated sample at: 1.26316
# Creating new interpolated sample at: 1.26773
# Creating new interpolated sample at: 1.27231
# Creating new interpolated sample at: 1.27689
# Creating new interpolated sample at: 1.28146
# Creating new interpolated sample at: 1.28604
# Creating new interpolated sample at: 1.29062
# Creating new interpolated sample at: 1.29519
# Creating new interpolated sample at: 1.29977
# Creating new interpolated sample at: 1.30435
# Creating new interpolated sample at: 1.30892
# Creating new interpolated sample at: 1.3135
# Creating new interpolated sample at: 1.31808
# Creating new interpolated sample at: 1.32265
# Creating new interpolated sample at: 1.32723
# Creating new interpolated sample at: 1.33181
# Creating new interpolated sample at: 1.33638
# Creating new interpolated sample at: 1.34096
# Creating new interpolated sample at: 1.34554
# Creating new interpolated sample at: 1.35011
# Creating new interpolated sample at: 1.35469
# Creating new interpolated sample at: 1.35927
# Creating new interpolated sample at: 1.36384
# Creating new interpolated sample at: 1.36842
# Creating new interpolated sample at: 1.373
# Creating new interpolated sample at: 1.37757
# Creating new interpolated sample at: 1.38215
# Creating new interpolated sample at: 1.38673
# Creating new interpolated sample at: 1.3913
# Creating new interpolated sample at: 1.39588
# Creating new interpolated sample at: 1.40046
# Creating new interpolated sample at: 1.40503
# Creating new interpolated sample at: 1.40961
# Creating new interpolated sample at: 1.41419
# Creating new interpolated sample at: 1.41876
# Creating new interpolated sample at: 1.42334
# Creating new interpolated sample at: 1.42792
# Creating new interpolated sample at: 1.43249
# Creating new interpolated sample at: 1.43707
# Creating new interpolated sample at: 1.44165
# Creating new interpolated sample at: 1.44622
# Creating new interpolated sample at: 1.4508
# Creating new interpolated sample at: 1.45538
# Creating new interpolated sample at: 1.45995
# Creating new interpolated sample at: 1.46453
# Creating new interpolated sample at: 1.46911
# Creating new interpolated sample at: 1.47368
# Creating new interpolated sample at: 1.47826
# Creating new interpolated sample at: 1.48284
# Creating new interpolated sample at: 1.48741
# Creating new interpolated sample at: 1.49199
# Creating new interpolated sample at: 1.49657
# Creating new interpolated sample at: 1.50114
# Creating new interpolated sample at: 1.50572
# Creating new interpolated sample at: 1.5103
# Creating new interpolated sample at: 1.51487
# Creating new interpolated sample at: 1.51945
# Creating new interpolated sample at: 1.52403
# Creating new interpolated sample at: 1.5286
# Creating new interpolated sample at: 1.53318
# Creating new interpolated sample at: 1.53776
# Creating new interpolated sample at: 1.54233
# Creating new interpolated sample at: 1.54691
# Creating new interpolated sample at: 1.55149
# Creating new interpolated sample at: 1.55606
# Creating new interpolated sample at: 1.56064
# Creating new interpolated sample at: 1.56522
# Creating new interpolated sample at: 1.56979
# Creating new interpolated sample at: 1.57437
# Creating new interpolated sample at: 1.57895
# Creating new interpolated sample at: 1.58352
# Creating new interpolated sample at: 1.5881
# Creating new interpolated sample at: 1.59268
# Creating new interpolated sample at: 1.59725
# Creating new interpolated sample at: 1.60183
# Creating new interpolated sample at: 1.60641
# Creating new interpolated sample at: 1.61098
# Creating new interpolated sample at: 1.61556
# Creating new interpolated sample at: 1.62014
# Creating new interpolated sample at: 1.62471
# Creating new interpolated sample at: 1.62929
# Creating new interpolated sample at: 1.63387
# Creating new interpolated sample at: 1.63844
# Creating new interpolated sample at: 1.64302
# Creating new interpolated sample at: 1.6476
# Creating new interpolated sample at: 1.65217
# Creating new interpolated sample at: 1.65675
# Creating new interpolated sample at: 1.66133
# Creating new interpolated sample at: 1.6659
# Creating new interpolated sample at: 1.67048
# Creating new interpolated sample at: 1.67506
# Creating new interpolated sample at: 1.67963
# Creating new interpolated sample at: 1.68421
# Creating new interpolated sample at: 1.68879
# Creating new interpolated sample at: 1.69336
# Creating new interpolated sample at: 1.69794
# Creating new interpolated sample at: 1.70252
# Creating new interpolated sample at: 1.70709
# Creating new interpolated sample at: 1.71167
# Creating new interpolated sample at: 1.71625
# Creating new interpolated sample at: 1.72082
# Creating new interpolated sample at: 1.7254
# Creating new interpolated sample at: 1.72998
# Creating new interpolated sample at: 1.73455
# Creating new interpolated sample at: 1.73913
# Creating new interpolated sample at: 1.74371
# Creating new interpolated sample at: 1.74828
# Creating new interpolated sample at: 1.75286
# Creating new interpolated sample at: 1.75744
# Creating new interpolated sample at: 1.76201
# Creating new interpolated sample at: 1.76659
# Creating new interpolated sample at: 1.77117
# Creating new interpolated sample at: 1.77574
# Creating new interpolated sample at: 1.78032
# Creating new interpolated sample at: 1.7849
# Creating new interpolated sample at: 1.78947
# Creating new interpolated sample at: 1.79405
# Creating new interpolated sample at: 1.79863
# Creating new interpolated sample at: 1.8032
# Creating new interpolated sample at: 1.80778
# Creating new interpolated sample at: 1.81236
# Creating new interpolated sample at: 1.81693
# Creating new interpolated sample at: 1.82151
# Creating new interpolated sample at: 1.82609
# Creating new interpolated sample at: 1.83066
# Creating new interpolated sample at: 1.83524
# Creating new interpolated sample at: 1.83982
# Creating new interpolated sample at: 1.84439
# Creating new interpolated sample at: 1.84897
# Creating new interpolated sample at: 1.85355
# Creating new interpolated sample at: 1.85812
# Creating new interpolated sample at: 1.8627
# Creating new interpolated sample at: 1.86728
# Creating new interpolated sample at: 1.87185
# Creating new interpolated sample at: 1.87643
# Creating new interpolated sample at: 1.88101
# Creating new interpolated sample at: 1.88558
# Creating new interpolated sample at: 1.89016
# Creating new interpolated sample at: 1.89474
# Creating new interpolated sample at: 1.89931
# Creating new interpolated sample at: 1.90389
# Creating new interpolated sample at: 1.90847
# Creating new interpolated sample at: 1.91304
# Creating new interpolated sample at: 1.91762
# Creating new interpolated sample at: 1.9222
# Creating new interpolated sample at: 1.92677
# Creating new interpolated sample at: 1.93135
# Creating new interpolated sample at: 1.93593
# Creating new interpolated sample at: 1.9405
# Creating new interpolated sample at: 1.94508
# Creating new interpolated sample at: 1.94966
# Creating new interpolated sample at: 1.95423
# Creating new interpolated sample at: 1.95881
# Creating new interpolated sample at: 1.96339
# Creating new interpolated sample at: 1.96796
# Creating new interpolated sample at: 1.97254
# Creating new interpolated sample at: 1.97712
# Creating new interpolated sample at: 1.98169
# Creating new interpolated sample at: 1.98627
# Creating new interpolated sample at: 1.99085
# Creating new interpolated sample at: 1.99542
# Creating new interpolated sample at: 2
# Number of interpolated snapshots is: 438
# Using 12 basis vectors out of 437.

# %%
# 14. Predict the state at t_final using DMD
dmd_prediction_timer.Start()
if myid == 0:
    print('Predicting density, momentum, and energy using DMD')

result_vars = [dmd_var.predict(ts[0]) for dmd_var in dmd_vars]
initial_dmd_sols = [mfem.Vector(result_var.getData(), result_var.dim()) for result_var in result_vars]
for i in range(4):
    block = u_block.GetBlock(i)
    block = initial_dmd_sols[i]
    #u_block.Update(initial_dmd_sols[i],offsets[i])

dmd_visit_dc = mfem.VisItDataCollection('DMD_DG_Euler', pmesh)
dmd_visit_dc.RegisterField('solution',mom)
if (visit):
    dmd_visit_dc.SetCycle(0)
    dmd_visit_dc.SetTime(0.0)
    dmd_visit_dc.Save()

if visit:
    for i in range(len(ts.size)):
        if (i==(len(ts)-1)) or (i%vis_steps==0):
            result_vars = [var.predict(ts[i]) for var in dmd_vars]
            dmd_sols = [mfem.Vector(result_var.getData(),result_var.dim()) for result_var in result_vars]
            for k in range(4):
                u_block.Update(dmd_sols[k],offsets[k])

            dmd_visit_dc.SetCycle(i)
            dmd_visit_dc.SetTime(ts[i])
            dmd_visit_dc.Save()
dmd_prediction_timer.Stop()
result_vars = [dmd_var.predict(t_final) for dmd_var in dmd_vars]
# Out:
# Predicting density, momentum, and energy using DMD

# %%
# 15. Calculate the relative error between the DMD final solution and the true solution.
dmd_solution_vars = [mfem.Vector(result_var.getData(),result_var.dim()) for result_var in result_vars]
diff_vars = [mfem.Vector(result_var.dim()) for result_var in result_vars]
for i in range(4):
    mfem.subtract_vector(dmd_solution_vars[i],true_solution_vars[i],\
                         diff_vars[i])
tot_diff_norm_vars = [sqrt(mfem.InnerProduct(MPI.COMM_WORLD,diff_var,diff_var)) for diff_var in diff_vars]
tot_true_solution_norm_vars = [sqrt(mfem.InnerProduct(MPI.COMM_WORLD,true_solution_var,true_solution_var))\
                                       for true_solution_var in true_solution_vars]

if myid==0:
    var_names = ['dens', 'x_mom', 'y_mom', 'e']
    for i in range(len(var_names)):
        rel_error = tot_diff_norm_vars[i]/tot_true_solution_norm_vars[i]
        print(f'Relative error of DMD {var_names[i]} at t_final: {t_final} is {rel_error:.10f}')

    print(f'Elapsed time for solving FOM: {fom_timer.duration:.6e}')
    print(f'Elapsed time for training DMD: {dmd_training_timer.duration:.6e}')
    print(f'Elapsed time for predicting DMD: {dmd_prediction_timer.duration:.6e}')
# Out:
# Relative error of DMD dens at t_final: 2.0 is 0.0003180880
# Relative error of DMD x_mom at t_final: 2.0 is 0.0002069844
# Relative error of DMD y_mom at t_final: 2.0 is 0.0012537761
# Relative error of DMD e at t_final: 2.0 is 0.0001376798
# Elapsed time for solving FOM: 3.632007e+02
# Elapsed time for training DMD: 4.629395e+01
# Elapsed time for predicting DMD: 1.548495e-01
